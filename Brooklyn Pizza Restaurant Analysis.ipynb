# %% [markdown]
# # **Broklyn Pizza Restaurant Analysis**

# %% [markdown]
# # **Imports**

# %%
# Imports 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly
# %matplotlib inline
from wordcloud import WordCloud
import re
import nltk
from nltk.corpus import stopwords

#Sklearn preprocessing
from sklearn import preprocessing,set_config
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder,StandardScaler,LabelEncoder

#Scipy
from scipy import stats
from scipy.stats import norm

#Sklearn Models
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn import preprocessing, set_config
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer,make_column_selector,make_column_transformer
from sklearn.linear_model import LogisticRegression
import warnings
from sklearn.decomposition import PCA

#Geospacial
import geopandas as gpd
import folium

# Warnings 
import warnings 
warnings.filterwarnings("ignore")

# Configuring diagrams
set_config(display = 'diagram')

# %% [markdown]
# # **Import Data**

# %%
# Loading merged Brooklyn Pizza Restaurants Data 
mdf = pd.read_csv('mdf')

# %%
# Ensuring the data loaded properly
mdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523 entries, 0 to 522
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CAMIS                  523 non-null    int64
#  1   DBA                    523 non-null    object
#  2   BORO                   523 non-null    object
#  3   BUILDING               523 non-null    object
#  4   STREET                 523 non-null    object
#  5   ZIPCODE                519 non-null    float64
#  6   CUISINE DESCRIPTION    523 non-null    object
#  7   INSPECTION DATE        523 non-null    object
#  8   ACTION                 523 non-null    object
#  9   VIOLATION CODE         521 non-null    object
#  10  VIOLATION DESCRIPTION  521 non-null    object
#  11  CRITICAL FLAG          523 non-null    object
#  12  SCORE                  523 non-null    float64
#  13  GRADE                  523 non-null    object
#  14  GRADE DATE             516 non-null    object
#  15  INSPECTION TYPE        523 non-null    object
#  16  Latitude               523 non-null    float64
#  17  Longitude              523 non-null    float64
#  18  Council District       519 non-null    float64
#  19  alias                  523 non-null    object
#  20  name                   523 non-null    object
#  21  image_url              523 non-null    object
#  22  url                    523 non-null    object
#  23  review_count           523 non-null    int64
#  24  categories             523 non-null    object
#  25  rating                 523 non-null    float64
#  26  coordinates            523 non-null    object
#  27  transactions           523 non-null    object
#  28  location               523 non-null    object
#  29  _merge                 523 non-null    object
# dtypes: float64(6), int64(2), object(22)
# memory usage: 122.7+ KB

# %% [markdown]
# # **Data Cleaning**

# %% [markdown]
# ## **Longitude and Latitude**

# %%
# Function to clean up longitude and latitude
def clean_coordinates(coord):
    try:
        # Convert to float
        coord = float(coord)
        
        # Ensure that longitude is in the range [-180, 180]
        if coord < -180 or coord > 180:
            return None  
        else:
            return coord
    except ValueError:
        return None
# Apply the cleaning function to 'Longitude' and 'Latitude' columns
mdf['Longitude'] = mdf['Longitude'].apply(clean_coordinates)
mdf['Latitude'] = mdf['Latitude'].apply(clean_coordinates)

# Drop rows with missing or invalid coordinates
mdf = mdf.dropna(subset=['Longitude', 'Latitude'])

# %% [markdown]
# ## **Outliers**

# %%
# Function to calculate z-score for a column
def calculate_zscore(column):
    z_scores = (column - column.mean()) / column.std()
    return z_scores

# Calculate z-scores for 'Longitude' and 'Latitude'
z_scores_longitude = calculate_zscore(mdf['Longitude'])
z_scores_latitude = calculate_zscore(mdf['Latitude'])

# Set a threshold for z-scores (e.g., 3 standard deviations)
z_threshold = 3

# Identify and remove outliers based on the threshold
outliers = (np.abs(z_scores_longitude) > z_threshold) | (np.abs(z_scores_latitude) > z_threshold)
mdf = mdf[~outliers]

# %% [markdown]
# # **Feature Enginering**

# %%
# Create a new column 'Restaurant Chain Indicator'
mdf['Chain Indicator'] = mdf['DBA'].duplicated(keep=False)

# %%
# Create a new column 'Full Address'
mdf['Full Address'] = mdf['BUILDING'] + ' ' + mdf['STREET']

# %%
# Define size categories
size_bins = [50, 100, 200, np.inf]
size_labels = ['Small', 'Medium', 'Large']

# Create 'Size Category' column
mdf['Size Category'] = pd.cut(mdf['review_count'], bins=size_bins, labels=size_labels)

# %% [markdown]
# # **Visualizations**

# %% [markdown]
# ## **Top 20 rated**

# %%
# Sort in descending order and select the top 20 rated restaurants
top_rated_restaurants = mdf.sort_values(by='rating', ascending=False).head(20)
print(top_rated_restaurants)
# Out:
#         CAMIS                     DBA      BORO BUILDING               STREET  \
# 497  50102007  ROME TO BROOKLYN PIZZA  Brooklyn      755         GRAND STREET
# 500  50102007  ROME TO BROOKLYN PIZZA  Brooklyn      755         GRAND STREET
# 499  50102007  ROME TO BROOKLYN PIZZA  Brooklyn      755         GRAND STREET
# 496  50102007  ROME TO BROOKLYN PIZZA  Brooklyn      755         GRAND STREET
# 498  50102007  ROME TO BROOKLYN PIZZA  Brooklyn      755         GRAND STREET
# 154  50086826          SAL'S PIZZERIA  Brooklyn      544       LORIMER STREET
# 151  50086826          SAL'S PIZZERIA  Brooklyn      544       LORIMER STREET
# 285  50089510            ROSA'S PIZZA  Brooklyn      374  METROPOLITAN AVENUE
# 137  50056980                 FAZIO'S  Brooklyn      709    KNICKERBOCKER AVE
# 305  50089510            ROSA'S PIZZA  Brooklyn      374  METROPOLITAN AVENUE
# 148  50125089          SAL'S PIZZERIA  Brooklyn      119       WYCKOFF AVENUE
# 300  50089510            ROSA'S PIZZA  Brooklyn      374  METROPOLITAN AVENUE
# 399  50141293          CHAMPION PIZZA  Brooklyn     1196        FULTON STREET
# 484  41434872   SAL & PAUL'S PIZZERIA  Brooklyn     1686        PITKIN AVENUE
# 485  41434872   SAL & PAUL'S PIZZERIA  Brooklyn     1686        PITKIN AVENUE
# 136  50056980                 FAZIO'S  Brooklyn      709    KNICKERBOCKER AVE
# 486  41434872   SAL & PAUL'S PIZZERIA  Brooklyn     1686        PITKIN AVENUE
# 487  41434872   SAL & PAUL'S PIZZERIA  Brooklyn     1686        PITKIN AVENUE
# 138  50056980                 FAZIO'S  Brooklyn      709    KNICKERBOCKER AVE
# 467  50055359                     OPS  Brooklyn      346        HIMROD STREET
#
#      ZIPCODE CUISINE DESCRIPTION INSPECTION DATE  \
# 497  11211.0               Pizza      01/23/2023
# 500  11211.0               Pizza      08/18/2021
# 499  11211.0               Pizza      08/18/2021
# 496  11211.0               Pizza      01/23/2023
# 498  11211.0               Pizza      08/18/2021
# 154  11211.0               Pizza      11/15/2022
# 151  11211.0               Pizza      11/15/2022
# 285  11211.0               Pizza      11/06/2023
# 137  11221.0               Pizza      12/19/2023
# 305  11211.0               Pizza      11/06/2023
# 148  11237.0               Pizza      12/06/2022
# 300  11211.0               Pizza      03/02/2022
# 399  11216.0               Pizza      10/25/2023
# 484  11212.0               Pizza      03/28/2022
# 485  11212.0               Pizza      04/24/2023
# 136  11221.0               Pizza      12/19/2023
# 486  11212.0               Pizza      04/24/2023
# 487  11212.0               Pizza      03/28/2022
# 138  11221.0               Pizza      08/05/2021
# 467  11237.0               Pizza      01/22/2020
#
#                                               ACTION VIOLATION CODE  ...  \
# 497  Violations were cited in the following area(s).            06D  ...
# 500  Violations were cited in the following area(s).            06F  ...
# 499  Violations were cited in the following area(s).            06B  ...
# 496  Violations were cited in the following area(s).            10F  ...
# 498  Violations were cited in the following area(s).            10B  ...
# 154  Violations were cited in the following area(s).            08A  ...
# 151  Violations were cited in the following area(s).            04L  ...
# 285  Violations were cited in the following area(s).            02B  ...
# 137  Violations were cited in the following area(s).            08A  ...
# 305  Violations were cited in the following area(s).            04L  ...
# 148  Violations were cited in the following area(s).            10F  ...
# 300  Violations were cited in the following area(s).            10F  ...
# 399  Violations were cited in the following area(s).            04N  ...
# 484  Violations were cited in the following area(s).            06D  ...
# 485  Violations were cited in the following area(s).            06D  ...
# 136  Violations were cited in the following area(s).            04L  ...
# 486  Violations were cited in the following area(s).            09E  ...
# 487  Violations were cited in the following area(s).            10F  ...
# 138  Violations were cited in the following area(s).            10F  ...
# 467  Violations were cited in the following area(s).            10F  ...
#
#     review_count                                         categories  rating  \
# 497          166  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 500          166  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 499          166  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 496          166  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 498          166  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 154           59             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 151           59             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 285          320  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 137          215  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 305          320  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 148           59             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 300          320  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 399          439             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 484           57             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 485           57             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 136          215  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 486           57             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 487           57             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 138          215  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 467          200  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
#
#                                            coordinates  \
# 497  {'latitude': 40.711886016839244, 'longitude': ...
# 500  {'latitude': 40.711886016839244, 'longitude': ...
# 499  {'latitude': 40.711886016839244, 'longitude': ...
# 496  {'latitude': 40.711886016839244, 'longitude': ...
# 498  {'latitude': 40.711886016839244, 'longitude': ...
# 154     {'latitude': 40.69276, 'longitude': -73.85883}
# 151     {'latitude': 40.69276, 'longitude': -73.85883}
# 285   {'latitude': 40.712192, 'longitude': -73.899997}
# 137     {'latitude': 40.69442, 'longitude': -73.91039}
# 305   {'latitude': 40.712192, 'longitude': -73.899997}
# 148     {'latitude': 40.69276, 'longitude': -73.85883}
# 300   {'latitude': 40.712192, 'longitude': -73.899997}
# 399  {'latitude': 40.7215270996094, 'longitude': -7...
# 484   {'latitude': 40.669419, 'longitude': -73.911059}
# 485   {'latitude': 40.669419, 'longitude': -73.911059}
# 136     {'latitude': 40.69442, 'longitude': -73.91039}
# 486   {'latitude': 40.669419, 'longitude': -73.911059}
# 487   {'latitude': 40.669419, 'longitude': -73.911059}
# 138     {'latitude': 40.69442, 'longitude': -73.91039}
# 467      {'latitude': 40.70276, 'longitude': -73.9171}
#
#                transactions  \
# 497  ['delivery', 'pickup']
# 500  ['delivery', 'pickup']
# 499  ['delivery', 'pickup']
# 496  ['delivery', 'pickup']
# 498  ['delivery', 'pickup']
# 154  ['delivery', 'pickup']
# 151  ['delivery', 'pickup']
# 285                      []
# 137  ['pickup', 'delivery']
# 305                      []
# 148  ['delivery', 'pickup']
# 300                      []
# 399  ['pickup', 'delivery']
# 484  ['delivery', 'pickup']
# 485  ['delivery', 'pickup']
# 136  ['pickup', 'delivery']
# 486  ['delivery', 'pickup']
# 487  ['delivery', 'pickup']
# 138  ['pickup', 'delivery']
# 467            ['delivery']
#
#                                               location  _merge  \
# 497  {'address1': '755 Grand St', 'address2': None,...    both
# 500  {'address1': '755 Grand St', 'address2': None,...    both
# 499  {'address1': '755 Grand St', 'address2': None,...    both
# 496  {'address1': '755 Grand St', 'address2': None,...    both
# 498  {'address1': '755 Grand St', 'address2': None,...    both
# 154  {'address1': '8507 Jamaica Ave', 'address2': '...    both
# 151  {'address1': '8507 Jamaica Ave', 'address2': '...    both
# 285  {'address1': '6265 Fresh Pond Rd', 'address2':...    both
# 137  {'address1': '709 Knickerbocker Ave', 'address...    both
# 305  {'address1': '6265 Fresh Pond Rd', 'address2':...    both
# 148  {'address1': '8507 Jamaica Ave', 'address2': '...    both
# 300  {'address1': '6265 Fresh Pond Rd', 'address2':...    both
# 399  {'address1': '17 Cleveland Pl', 'address2': No...    both
# 484  {'address1': '1686 Pitkin Ave', 'address2': ''...    both
# 485  {'address1': '1686 Pitkin Ave', 'address2': ''...    both
# 136  {'address1': '709 Knickerbocker Ave', 'address...    both
# 486  {'address1': '1686 Pitkin Ave', 'address2': ''...    both
# 487  {'address1': '1686 Pitkin Ave', 'address2': ''...    both
# 138  {'address1': '709 Knickerbocker Ave', 'address...    both
# 467  {'address1': '346 Himrod St', 'address2': None...    both
#
#      Chain Indicator             Full Address Size Category
# 497             True         755 GRAND STREET        Medium
# 500             True         755 GRAND STREET        Medium
# 499             True         755 GRAND STREET        Medium
# 496             True         755 GRAND STREET        Medium
# 498             True         755 GRAND STREET        Medium
# 154             True       544 LORIMER STREET         Small
# 151             True       544 LORIMER STREET         Small
# 285             True  374 METROPOLITAN AVENUE         Large
# 137             True    709 KNICKERBOCKER AVE         Large
# 305             True  374 METROPOLITAN AVENUE         Large
# 148             True       119 WYCKOFF AVENUE         Small
# 300             True  374 METROPOLITAN AVENUE         Large
# 399             True       1196 FULTON STREET         Large
# 484             True       1686 PITKIN AVENUE         Small
# 485             True       1686 PITKIN AVENUE         Small
# 136             True    709 KNICKERBOCKER AVE         Large
# 486             True       1686 PITKIN AVENUE         Small
# 487             True       1686 PITKIN AVENUE         Small
# 138             True    709 KNICKERBOCKER AVE         Large
# 467             True        346 HIMROD STREET        Medium
#
# [20 rows x 33 columns]

# %%
# Group by 'name' and calculate the mean rating for each restaurant
mean_ratings = mdf.groupby('name')['rating'].mean().reset_index()

# Sort by mean rating in descending order and select the top 20
top_rated_restaurants = mean_ratings.sort_values(by='rating', ascending=False).head(20)

# Create a vertical bar plot
plt.figure(figsize=(12, 8))
plt.bar(top_rated_restaurants['name'], top_rated_restaurants['rating'], color='skyblue')
plt.xlabel('Restaurant Name')
plt.ylabel('Average Rating')
plt.title('Top 20 Highest-Rated Restaurants (Average Rating)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## **Top 20 Review Count**

# %%
# Group by 'name' and calculate the total review count for each restaurant
total_reviews = mdf.groupby('name')['review_count'].sum().reset_index()

# Sort by total review count in descending order and select the top 20
top_reviewed_restaurants = total_reviews.sort_values(by='review_count', ascending=False).head(20)
# Create a vertical bar plot
plt.figure(figsize=(12, 8))
plt.bar(top_reviewed_restaurants['name'], top_reviewed_restaurants['review_count'], color='salmon')
plt.xlabel('Restaurant Name')
plt.ylabel('Total Review Count')
plt.title('Top 20 Restaurants with the Most Reviews')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# %% [markdown]
# ## **Size Category Count**

# %%
# Count the number of restaurants in each size category
size_category_counts = mdf['Size Category'].value_counts()

# Create a vertical bar plot
plt.figure(figsize=(10, 6))
size_category_counts.plot(kind='bar', color='lightgreen')
plt.xlabel('Size Category')
plt.ylabel('Number of Restaurants')
plt.title('Distribution of Restaurants by Size Category')
plt.xticks(rotation=0, ha='center')  # Rotate x-axis labels if needed
plt.tight_layout()
# Show the plot
plt.show()

# %% [markdown]
# ## **Geospatial**

# %%
#Create a GeoDataFrame from the DataFrame
geometry = gpd.points_from_xy(mdf['Longitude'], mdf['Latitude'])
gdf = gpd.GeoDataFrame(mdf, geometry=geometry)

# Plot using GeoPandas and Matplotlib
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
ax = world.plot(color='lightgrey', edgecolor='black')
gdf.plot(ax=ax, marker='o', color='red', markersize=10, alpha=0.5)
plt.title('Geospatial Visualization with GeoPandas and Matplotlib')
plt.show()

# Creating an interactive map using Folium
m = folium.Map(location=[mdf['Latitude'].mean(), mdf['Longitude'].mean()], zoom_start=1)

for index, row in mdf.iterrows():
    popup_content = (
        f"Name: {row['name']}<br>"
        f"Latitude: {row['Latitude']}, Longitude: {row['Longitude']}<br>"
        f"Rating: {row['rating']}<br>"
        f"Review Count: {row['review_count']}<br>"
        f"SCORE: {row['SCORE']}<br>"
        f"Size Category: {row['Size Category']}<br>"
        f"Full Address: {row['Full Address']}<br>"
        f"Chain Indicator: {row['Chain Indicator']}<br>"
        f"Transaction: {row['transactions']}<br"
        f"Grade: {row['GRADE']}"
    )
# Create a marker with the customized popup content and add it to the map
    folium.Marker([row['Latitude'], row['Longitude']], popup=folium.Popup(popup_content, max_width=300)).add_to(m)

# Save the map to an HTML file
m.save('folium_map.html')

# Showing the geospatial viz
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_67bd10e24e8e04dafec1a4b049b3b210 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_67bd10e24e8e04dafec1a4b049b3b210&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_67bd10e24e8e04dafec1a4b049b3b210 = L.map(
#                 &quot;map_67bd10e24e8e04dafec1a4b049b3b210&quot;,
#                 {
#                     center: [40.68323920584778, -73.9629142726361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cbfa500a8ba3cae980a9fbfbfe40395d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cbfa500a8ba3cae980a9fbfbfe40395d.addTo(map_67bd10e24e8e04dafec1a4b049b3b210);
#
#
#             var marker_7ec361a61a8205871677c401ff3bee99 = L.marker(
#                 [40.713501148283, -73.961918869626],
#                 {}
#             ).addTo(map_67bd10e24e8e04dafec1a4b049b3b210);
#
#
#         var popup_92129c8ee884bb7bc46fdbf2f62f149e = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_e10e244e7bda187e9dc8d20baee37fd9 = $(`&lt;div id=&quot;html_e10e244e7bda187e9dc8d20baee37fd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: FINI PIZZA&lt;br&gt;Latitude: 40.713501148283, Longitude: -73.961918869626&lt;br&gt;Rating: 4.0&lt;br&gt;Review Count: 120&lt;br&gt;SCORE: 10.0&lt;br&gt;Size Category: Medium&lt;br&gt;Full Address: 305 BEDFORD AVENUE&lt;br&gt;Chain Indicator: True&lt;br&gt;Transaction: []&lt;brGrade: A&lt;/div&gt;`)[0];
#                 popup_92129c8ee884bb7bc46fdbf2f62f149e.setContent(html_e10e244e7bda187e9dc8d20baee37fd9);
#
#
#
#         marker_7ec361a61a8205871677c401ff3bee99.bindPopup(popup_92129c8ee884bb7bc46fdbf2f62f149e)
#         ;
#
#
#
#
#             var marker_2dc92b324d3dfa3bafa74eb1b346d9ff = L.marker(
#                 [40.683446896895, -73.975691312176],
#                 {}
#             ).addTo(map_67bd10e24e8e04dafec1a4b049b3b210);
#
#
#         var popup_3a6874135e086e5a3ac8804343e8148d = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_02f850bc617c64e827d54d3e43f7bde9 = $(`&lt;div id=&quot;html_02f850bc617c64e827d54d3e43f7bde9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: FINI PIZZA&lt;br&gt;Latitude: 40.683446896895, Longitude: -73.975691312176&lt;br&gt;Rating: 4.0&lt;br&gt;Review Count: 120&lt;br&gt;SCORE: 19.0&lt;br&gt;Size Category: Medium&lt;br&gt;Full Address: 620 ATLANTIC AVENUE&lt;br&gt;Chain Indicator: True&lt;br&gt;Transaction: []&lt;brGrade: N&lt;/div&gt;`)[0];
#                 popup_3a6874135e086e5a3ac8804343e8148d.setContent(html_02f850bc617c64e827d54d3e43f7bde9);
#
#
#
#         marker_2dc92b324d3dfa3bafa74eb1b346d9ff.bindPopup(popup_3a6874135e086e5a3ac8804343e8148d)
#         ;
#
#
#
#
#             var marker_e3da8f097f43b541c9bf0eab62befdc7 = L.marker(
#                 [40.683446896895, -73.975691312176],
#                 {}
#             ).addTo(map_67bd10e24e8e04dafec1a4b049b3b210);
#
#
#         var popup_417c1d74fc042448a4f01d9f273bb68d = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_cd34768384e9dc1bbdbadee2d272137f = $(`&lt;div id=&quot;html_cd34768384e9dc1bbdbadee2d272137f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: FINI PIZZA&lt;br&gt;Latitude: 40.683446896895, Longitude: -73.975691312176&lt;br&gt;Rating: 4.0&lt;br&gt;Review Count: 120&lt;br&gt;SCORE: 19.0&lt;br&gt;Size Category: Medium&lt;br&gt;Full Address: 620 ATLANTIC AVENUE&lt;br&gt;Chain Indicator: True&lt;br&gt;Transaction: []&lt;brGrade: N&lt;/div&gt;`)[0];
#                 popup_417c1d74fc042448a4f01d9f273bb68d.setContent(html_cd34768384e9dc1bbdbadee2d272137f);
#
#
#
#         marker_e3da8f097f43b541c9bf0eab62befdc7.bindPopup(popup_417c1d74fc042448a4f01d9f273bb68d)
#         ;
#
#
#
#
#             var marker_29242108f120a7f783d4783ee54e058d = L.marker(
#                 [40.713501148283, -73.961918869626],
#                 {}
#             ).addTo(map_67bd10e24e8e04dafec1a4b049b3b210);
#
#
#         var popup_8881612bbbab007dde1c067f3578e6fe = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_bb4e77c8d2baddcb6e8130243a125577 = $(`&lt;div id=&quot;html_bb4e77c8d2baddcb6e8130243a125577&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: FINI PIZZA&lt;br&gt;Latitude: 40.713501148283, Longitude: -73.961918869626&lt;br&gt;Rating: 4.0&lt;br&gt;Review Count: 120&lt;br&gt;SCORE: 10.0&lt;br&gt;Size Category: Medium&lt;br&gt;Full Address: 305 BEDFORD AVENUE&lt;br&gt;Chain Indicator: True&lt;br&gt;Transaction: []&lt;brGrade: A&lt;/div&gt;`)[0];
#                 popup_8881612bbbab007dde1c067f3578e6fe.setContent(html_bb4e77c8d2baddcb6e8130243a125577);
