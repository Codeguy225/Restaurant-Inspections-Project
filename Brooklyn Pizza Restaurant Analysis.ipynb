# %% [markdown]
# # **Brooklyn Pizza Restaurant Analysis**

# %% [markdown]
# # **Imports**

# %%
# Imports 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly
# %matplotlib inline
from wordcloud import WordCloud
import re
import nltk
from nltk.corpus import stopwords

#Sklearn preprocessing
from sklearn import preprocessing,set_config
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder,StandardScaler,LabelEncoder

#Scipy
from scipy import stats
from scipy.stats import norm

#Sklearn Models
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn import preprocessing, set_config
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer,make_column_selector,make_column_transformer
from sklearn.linear_model import LogisticRegression
import warnings
from sklearn.decomposition import PCA

#Geospacial
import geopandas as gpd
import folium

# Warnings 
import warnings 
warnings.filterwarnings("ignore")

# Configuring diagrams
set_config(display = 'diagram')

# %% [markdown]
# # **Import Data**

# %%
# Loading merged Brooklyn Pizza Restaurants Data 
mdf = pd.read_csv('mdf')

# %%
# Ensuring the data loaded properly
mdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CAMIS                  652 non-null    int64
#  1   DBA                    652 non-null    object
#  2   BORO                   652 non-null    object
#  3   BUILDING               652 non-null    object
#  4   STREET                 652 non-null    object
#  5   ZIPCODE                644 non-null    float64
#  6   CUISINE DESCRIPTION    652 non-null    object
#  7   INSPECTION DATE        652 non-null    object
#  8   ACTION                 652 non-null    object
#  9   VIOLATION CODE         649 non-null    object
#  10  VIOLATION DESCRIPTION  649 non-null    object
#  11  CRITICAL FLAG          652 non-null    object
#  12  SCORE                  652 non-null    float64
#  13  GRADE                  652 non-null    object
#  14  GRADE DATE             652 non-null    object
#  15  INSPECTION TYPE        652 non-null    object
#  16  Latitude               652 non-null    float64
#  17  Longitude              652 non-null    float64
#  18  Council District       644 non-null    float64
#  19  alias                  652 non-null    object
#  20  name                   652 non-null    object
#  21  image_url              652 non-null    object
#  22  url                    652 non-null    object
#  23  review_count           652 non-null    int64
#  24  categories             652 non-null    object
#  25  rating                 652 non-null    float64
#  26  coordinates            652 non-null    object
#  27  transactions           652 non-null    object
#  28  location               652 non-null    object
#  29  _merge                 652 non-null    object
# dtypes: float64(6), int64(2), object(22)
# memory usage: 152.9+ KB

# %% [markdown]
# # **Data Cleaning**

# %% [markdown]
# ## **Longitude and Latitude**

# %%
# Function to clean up longitude and latitude
def clean_coordinates(coord):
    try:
        # Convert to float
        coord = float(coord)
        
        # Ensure that longitude is in the range [-180, 180]
        if coord < -180 or coord > 180:
            return None  
        else:
            return coord
    except ValueError:
        return None
# Apply the cleaning function to 'Longitude' and 'Latitude' columns
mdf['Longitude'] = mdf['Longitude'].apply(clean_coordinates)
mdf['Latitude'] = mdf['Latitude'].apply(clean_coordinates)

# Drop rows with missing or invalid coordinates
mdf = mdf.dropna(subset=['Longitude', 'Latitude'])

# %% [markdown]
# ## **Outliers**

# %%
# Function to calculate z-score for a column
def calculate_zscore(column):
    z_scores = (column - column.mean()) / column.std()
    return z_scores

# Calculate z-scores for 'Longitude' and 'Latitude'
z_scores_longitude = calculate_zscore(mdf['Longitude'])
z_scores_latitude = calculate_zscore(mdf['Latitude'])

# Set a threshold for z-scores (e.g., 3 standard deviations)
z_threshold = 3

# Identify and remove outliers based on the threshold
outliers = (np.abs(z_scores_longitude) > z_threshold) | (np.abs(z_scores_latitude) > z_threshold)
mdf = mdf[~outliers]

# %% [markdown]
# # **Feature Enginering**

# %%
# Create a new column 'Restaurant Chain Indicator'
mdf['Chain Indicator'] = mdf['DBA'].duplicated(keep=False)

# %%
# Create a new column 'Full Address'
mdf['Full Address'] = mdf['BUILDING'] + ' ' + mdf['STREET']

# %%
# Define size categories
size_bins = [50, 100, 200, np.inf]
size_labels = ['Small', 'Medium', 'Large']

# Create 'Size Category' column
mdf['Size Category'] = pd.cut(mdf['review_count'], bins=size_bins, labels=size_labels)

# %% [markdown]
# # **Visualizations**

# %% [markdown]
# ## **Top 20 rated**

# %%
# Sort in descending order and select the top 20 rated restaurants
top_rated_restaurants = mdf.sort_values(by='rating', ascending=False).head(20)
print(top_rated_restaurants)
# Out:
#         CAMIS                     DBA      BORO BUILDING               STREET  \
# 613  50102007  ROME TO BROOKLYN PIZZA  Brooklyn      755         GRAND STREET
# 612  50102007  ROME TO BROOKLYN PIZZA  Brooklyn      755         GRAND STREET
# 614  50102007  ROME TO BROOKLYN PIZZA  Brooklyn      755         GRAND STREET
# 610  50102007  ROME TO BROOKLYN PIZZA  Brooklyn      755         GRAND STREET
# 611  50102007  ROME TO BROOKLYN PIZZA  Brooklyn      755         GRAND STREET
# 211  50056980                 FAZIO'S  Brooklyn      709    KNICKERBOCKER AVE
# 448  50055359                     OPS  Brooklyn      346        HIMROD STREET
# 213  50056980                 FAZIO'S  Brooklyn      709    KNICKERBOCKER AVE
# 212  50056980                 FAZIO'S  Brooklyn      709    KNICKERBOCKER AVE
# 452  50055359                     OPS  Brooklyn      346        HIMROD STREET
# 451  50055359                     OPS  Brooklyn      346        HIMROD STREET
# 450  50055359                     OPS  Brooklyn      346        HIMROD STREET
# 449  50055359                     OPS  Brooklyn      346        HIMROD STREET
# 178  50116710            BROOKLYN DOP  Brooklyn      237             5 AVENUE
# 210  50056980                 FAZIO'S  Brooklyn      709    KNICKERBOCKER AVE
# 177  50116710            BROOKLYN DOP  Brooklyn      237             5 AVENUE
# 51   50089510            ROSA'S PIZZA  Brooklyn      374  METROPOLITAN AVENUE
# 176  50116710            BROOKLYN DOP  Brooklyn      237             5 AVENUE
# 547  50141293          CHAMPION PIZZA  Brooklyn     1196        FULTON STREET
# 553  50141293          CHAMPION PIZZA  Brooklyn     1196        FULTON STREET
#
#      ZIPCODE CUISINE DESCRIPTION INSPECTION DATE  \
# 613  11211.0               Pizza      08/18/2021
# 612  11211.0               Pizza      08/18/2021
# 614  11211.0               Pizza      01/23/2023
# 610  11211.0               Pizza      01/23/2023
# 611  11211.0               Pizza      08/18/2021
# 211  11221.0               Pizza      12/19/2023
# 448  11237.0               Pizza      12/10/2022
# 213  11221.0               Pizza      08/05/2021
# 212  11221.0               Pizza      08/05/2021
# 452  11237.0               Pizza      01/22/2020
# 451  11237.0               Pizza      01/22/2020
# 450  11237.0               Pizza      01/22/2020
# 449  11237.0               Pizza      12/10/2022
# 178  11215.0               Pizza      03/22/2023
# 210  11221.0               Pizza      12/19/2023
# 177  11215.0               Pizza      03/22/2023
# 51   11211.0               Pizza      11/06/2023
# 176  11215.0               Pizza      03/22/2023
# 547  11216.0               Pizza      10/25/2023
# 553  11216.0               Pizza      10/25/2023
#
#                                               ACTION VIOLATION CODE  ...  \
# 613  Violations were cited in the following area(s).            10B  ...
# 612  Violations were cited in the following area(s).            06F  ...
# 614  Violations were cited in the following area(s).            06D  ...
# 610  Violations were cited in the following area(s).            10F  ...
# 611  Violations were cited in the following area(s).            06B  ...
# 211  Violations were cited in the following area(s).            08A  ...
# 448  Violations were cited in the following area(s).            06D  ...
# 213  Violations were cited in the following area(s).            10F  ...
# 212  Violations were cited in the following area(s).            06C  ...
# 452  Violations were cited in the following area(s).            06D  ...
# 451  Violations were cited in the following area(s).            06C  ...
# 450  Violations were cited in the following area(s).            10F  ...
# 449  Violations were cited in the following area(s).            02G  ...
# 178  Violations were cited in the following area(s).            10B  ...
# 210  Violations were cited in the following area(s).            02B  ...
# 177  Violations were cited in the following area(s).            06D  ...
# 51   Violations were cited in the following area(s).            08A  ...
# 176  Violations were cited in the following area(s).            10F  ...
# 547  Violations were cited in the following area(s).            08A  ...
# 553  Violations were cited in the following area(s).            10F  ...
#
#     review_count                                         categories  rating  \
# 613          166  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 612          166  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 614          166  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 610          166  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 611          166  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 211          215  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 448          200  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 213          215  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 212          215  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 452          200  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 451          200  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 450          200  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 449          200  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 178           45             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 210          215  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 177           45             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 51           320  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 176           45             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 547          439             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 553          439             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
#
#                                            coordinates  \
# 613  {'latitude': 40.711886016839244, 'longitude': ...
# 612  {'latitude': 40.711886016839244, 'longitude': ...
# 614  {'latitude': 40.711886016839244, 'longitude': ...
# 610  {'latitude': 40.711886016839244, 'longitude': ...
# 611  {'latitude': 40.711886016839244, 'longitude': ...
# 211     {'latitude': 40.69442, 'longitude': -73.91039}
# 448      {'latitude': 40.70276, 'longitude': -73.9171}
# 213     {'latitude': 40.69442, 'longitude': -73.91039}
# 212     {'latitude': 40.69442, 'longitude': -73.91039}
# 452      {'latitude': 40.70276, 'longitude': -73.9171}
# 451      {'latitude': 40.70276, 'longitude': -73.9171}
# 450      {'latitude': 40.70276, 'longitude': -73.9171}
# 449      {'latitude': 40.70276, 'longitude': -73.9171}
# 178      {'latitude': 40.67526, 'longitude': -73.9811}
# 210     {'latitude': 40.69442, 'longitude': -73.91039}
# 177      {'latitude': 40.67526, 'longitude': -73.9811}
# 51    {'latitude': 40.712192, 'longitude': -73.899997}
# 176      {'latitude': 40.67526, 'longitude': -73.9811}
# 547  {'latitude': 40.7215270996094, 'longitude': -7...
# 553  {'latitude': 40.7215270996094, 'longitude': -7...
#
#                transactions  \
# 613  ['delivery', 'pickup']
# 612  ['delivery', 'pickup']
# 614  ['delivery', 'pickup']
# 610  ['delivery', 'pickup']
# 611  ['delivery', 'pickup']
# 211  ['pickup', 'delivery']
# 448            ['delivery']
# 213  ['pickup', 'delivery']
# 212  ['pickup', 'delivery']
# 452            ['delivery']
# 451            ['delivery']
# 450            ['delivery']
# 449            ['delivery']
# 178                      []
# 210  ['pickup', 'delivery']
# 177                      []
# 51                       []
# 176                      []
# 547  ['pickup', 'delivery']
# 553  ['pickup', 'delivery']
#
#                                               location  _merge  \
# 613  {'address1': '755 Grand St', 'address2': None,...    both
# 612  {'address1': '755 Grand St', 'address2': None,...    both
# 614  {'address1': '755 Grand St', 'address2': None,...    both
# 610  {'address1': '755 Grand St', 'address2': None,...    both
# 611  {'address1': '755 Grand St', 'address2': None,...    both
# 211  {'address1': '709 Knickerbocker Ave', 'address...    both
# 448  {'address1': '346 Himrod St', 'address2': None...    both
# 213  {'address1': '709 Knickerbocker Ave', 'address...    both
# 212  {'address1': '709 Knickerbocker Ave', 'address...    both
# 452  {'address1': '346 Himrod St', 'address2': None...    both
# 451  {'address1': '346 Himrod St', 'address2': None...    both
# 450  {'address1': '346 Himrod St', 'address2': None...    both
# 449  {'address1': '346 Himrod St', 'address2': None...    both
# 178  {'address1': '237 5th Ave', 'address2': '', 'a...    both
# 210  {'address1': '709 Knickerbocker Ave', 'address...    both
# 177  {'address1': '237 5th Ave', 'address2': '', 'a...    both
# 51   {'address1': '6265 Fresh Pond Rd', 'address2':...    both
# 176  {'address1': '237 5th Ave', 'address2': '', 'a...    both
# 547  {'address1': '17 Cleveland Pl', 'address2': No...    both
# 553  {'address1': '17 Cleveland Pl', 'address2': No...    both
#
#      Chain Indicator             Full Address Size Category
# 613             True         755 GRAND STREET        Medium
# 612             True         755 GRAND STREET        Medium
# 614             True         755 GRAND STREET        Medium
# 610             True         755 GRAND STREET        Medium
# 611             True         755 GRAND STREET        Medium
# 211             True    709 KNICKERBOCKER AVE         Large
# 448             True        346 HIMROD STREET        Medium
# 213             True    709 KNICKERBOCKER AVE         Large
# 212             True    709 KNICKERBOCKER AVE         Large
# 452             True        346 HIMROD STREET        Medium
# 451             True        346 HIMROD STREET        Medium
# 450             True        346 HIMROD STREET        Medium
# 449             True        346 HIMROD STREET        Medium
# 178             True             237 5 AVENUE           NaN
# 210             True    709 KNICKERBOCKER AVE         Large
# 177             True             237 5 AVENUE           NaN
# 51              True  374 METROPOLITAN AVENUE         Large
# 176             True             237 5 AVENUE           NaN
# 547             True       1196 FULTON STREET         Large
# 553             True       1196 FULTON STREET         Large
#
# [20 rows x 33 columns]

# %%
# Group by 'name' and calculate the mean rating for each restaurant
mean_ratings = mdf.groupby('name')['rating'].mean().reset_index()

# Sort by mean rating in descending order and select the top 20
top_rated_restaurants = mean_ratings.sort_values(by='rating', ascending=False).head(20)

# Create a vertical bar plot
plt.figure(figsize=(12, 8))
plt.bar(top_rated_restaurants['name'], top_rated_restaurants['rating'], color='skyblue')
plt.xlabel('Restaurant Name')
plt.ylabel('Average Rating')
plt.title('Top 20 Highest-Rated Restaurants (Average Rating)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## **Top 20 Review Count**

# %%
# Group by 'name' and calculate the total review count for each restaurant
total_reviews = mdf.groupby('name')['review_count'].sum().reset_index()

# Sort by total review count in descending order and select the top 20
top_reviewed_restaurants = total_reviews.sort_values(by='review_count', ascending=False).head(20)
# Create a vertical bar plot
plt.figure(figsize=(12, 8))
plt.bar(top_reviewed_restaurants['name'], top_reviewed_restaurants['review_count'], color='salmon')
plt.xlabel('Restaurant Name')
plt.ylabel('Total Review Count')
plt.title('Top 20 Restaurants with the Most Reviews')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# %% [markdown]
# ## **Size Category Count**

# %%
# Count the number of restaurants in each size category
size_category_counts = mdf['Size Category'].value_counts()

# Create a vertical bar plot
plt.figure(figsize=(10, 6))
size_category_counts.plot(kind='bar', color='lightgreen')
plt.xlabel('Size Category')
plt.ylabel('Number of Restaurants')
plt.title('Distribution of Restaurants by Size Category')
plt.xticks(rotation=0, ha='center')  # Rotate x-axis labels if needed
plt.tight_layout()
# Show the plot
plt.show()

# %% [markdown]
# ## **Geospatial**

# %%
#Create a GeoDataFrame from the DataFrame
geometry = gpd.points_from_xy(mdf['Longitude'], mdf['Latitude'])
gdf = gpd.GeoDataFrame(mdf, geometry=geometry)

# Plot using GeoPandas and Matplotlib
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
ax = world.plot(color='lightgrey', edgecolor='black')
gdf.plot(ax=ax, marker='o', color='red', markersize=10, alpha=0.5)
plt.title('Geospatial Visualization with GeoPandas and Matplotlib')
plt.show()

# Creating an interactive map using Folium
m = folium.Map(location=[mdf['Latitude'].mean(), mdf['Longitude'].mean()], zoom_start=1)

for index, row in mdf.iterrows():
    popup_content = (
        f"Name: {row['name']}<br>"
        f"Latitude: {row['Latitude']}, Longitude: {row['Longitude']}<br>"
        f"Rating: {row['rating']}<br>"
        f"Review Count: {row['review_count']}<br>"
        f"SCORE: {row['SCORE']}<br>"
        f"Size Category: {row['Size Category']}<br>"
        f"Full Address: {row['Full Address']}<br>"
        f"Chain Indicator: {row['Chain Indicator']}<br>"
        f"Transaction: {row['transactions']}<br"
        f"Grade: {row['GRADE']}"
    )
# Create a marker with the customized popup content and add it to the map
    folium.Marker([row['Latitude'], row['Longitude']], popup=folium.Popup(popup_content, max_width=300)).add_to(m)

# Save the map to an HTML file
m.save('folium_map.html')

# Showing the geospatial viz
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_330937862a282e19b31e1355385b2552 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_330937862a282e19b31e1355385b2552&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_330937862a282e19b31e1355385b2552 = L.map(
#                 &quot;map_330937862a282e19b31e1355385b2552&quot;,
#                 {
#                     center: [40.682099240333535, -73.96295549931268],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_39365931466757c894de08cfd514f3ee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_39365931466757c894de08cfd514f3ee.addTo(map_330937862a282e19b31e1355385b2552);
#
#
#             var marker_1efa27bf96378c779a56945c743a7b03 = L.marker(
#                 [40.7140670496, -73.955616725691],
#                 {}
#             ).addTo(map_330937862a282e19b31e1355385b2552);
#
#
#         var popup_c2e6ae80bc2b66be2bc020c1392cbabd = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_985f79cac6aa16e882a9a746990b73ec = $(`&lt;div id=&quot;html_985f79cac6aa16e882a9a746990b73ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: ROSA&#x27;S PIZZA&lt;br&gt;Latitude: 40.7140670496, Longitude: -73.955616725691&lt;br&gt;Rating: 4.0&lt;br&gt;Review Count: 197&lt;br&gt;SCORE: 59.0&lt;br&gt;Size Category: Medium&lt;br&gt;Full Address: 374 METROPOLITAN AVENUE&lt;br&gt;Chain Indicator: True&lt;br&gt;Transaction: [&#x27;delivery&#x27;, &#x27;pickup&#x27;]&lt;brGrade: C&lt;/div&gt;`)[0];
#                 popup_c2e6ae80bc2b66be2bc020c1392cbabd.setContent(html_985f79cac6aa16e882a9a746990b73ec);
#
#
#
#         marker_1efa27bf96378c779a56945c743a7b03.bindPopup(popup_c2e6ae80bc2b66be2bc020c1392cbabd)
#         ;
#
#
#
#
#             var marker_0faf8fb184c291a1528fa4aba72a9735 = L.marker(
#                 [40.7140670496, -73.955616725691],
#                 {}
#             ).addTo(map_330937862a282e19b31e1355385b2552);
#
#
#         var popup_28045c721b258cdbd82c07a50f29ca01 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_84e3a5034f06d4764ae7aba7a17dc9ad = $(`&lt;div id=&quot;html_84e3a5034f06d4764ae7aba7a17dc9ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: ROSA&#x27;S PIZZA&lt;br&gt;Latitude: 40.7140670496, Longitude: -73.955616725691&lt;br&gt;Rating: 4.5&lt;br&gt;Review Count: 320&lt;br&gt;SCORE: 59.0&lt;br&gt;Size Category: Large&lt;br&gt;Full Address: 374 METROPOLITAN AVENUE&lt;br&gt;Chain Indicator: True&lt;br&gt;Transaction: []&lt;brGrade: C&lt;/div&gt;`)[0];
#                 popup_28045c721b258cdbd82c07a50f29ca01.setContent(html_84e3a5034f06d4764ae7aba7a17dc9ad);
#
#
#
#         marker_0faf8fb184c291a1528fa4aba72a9735.bindPopup(popup_28045c721b258cdbd82c07a50f29ca01)
#         ;
#
#
#
#
#             var marker_229300b79caa3ad0de6490c6920fbe32 = L.marker(
#                 [40.7140670496, -73.955616725691],
#                 {}
#             ).addTo(map_330937862a282e19b31e1355385b2552);
#
#
#         var popup_10169412caaf9f4072c943b1965b691d = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_6e378d1056802a144adc993a9e61e666 = $(`&lt;div id=&quot;html_6e378d1056802a144adc993a9e61e666&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: ROSA&#x27;S PIZZA&lt;br&gt;Latitude: 40.7140670496, Longitude: -73.955616725691&lt;br&gt;Rating: 4.0&lt;br&gt;Review Count: 46&lt;br&gt;SCORE: 59.0&lt;br&gt;Size Category: nan&lt;br&gt;Full Address: 374 METROPOLITAN AVENUE&lt;br&gt;Chain Indicator: True&lt;br&gt;Transaction: [&#x27;delivery&#x27;, &#x27;pickup&#x27;]&lt;brGrade: C&lt;/div&gt;`)[0];
#                 popup_10169412caaf9f4072c943b1965b691d.setContent(html_6e378d1056802a144adc993a9e61e666);
#
#
#
#         marker_229300b79caa3ad0de6490c6920fbe32.bindPopup(popup_10169412caaf9f4072c943b1965b691d)
#         ;
#
#
#
#
#             var marker_e9ad87ceab9a969b0fe2545ec3794c56 = L.marker(
#                 [40.7140670496, -73.955616725691],
#                 {}
#             ).addTo(map_330937862a282e19b31e1355385b2552);
#
#
#         var popup_7733e33b73506676b0c2405f7829d01d = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_781fd3dc05245270702c0cd7e1cca6cc = $(`&lt;div id=&quot;html_781fd3dc05245270702c0cd7e1cca6cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: ROSA&#x27;S PIZZA&lt;br&gt;Latitude: 40.7140670496, Longitude: -73.955616725691&lt;br&gt;Rating: 4.0&lt;br&gt;Review Count: 458&lt;br&gt;SCORE: 59.0&lt;br&gt;Size Category: Large&lt;br&gt;Full Address: 374 METROPOLITAN AVENUE&lt;br&gt;Chain Indicator: True&lt;br&gt;Transaction: []&lt;brGrade: C&lt;/div&gt;`)[0];
