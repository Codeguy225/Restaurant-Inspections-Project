# %% [markdown]
# # **NYC Restaurant Yelp Reviews**

# %% [markdown]
# # **Imports**

# %%
# Imports 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports 
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
# Load API Credentials:
with open("F:\\Desktop Backup\\talen\\.secret\\yelp_api.json",'r') as f:
    login = json.load(f)

# %%
# Show Login Keys:
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'],timeout_s=5.0)

# %%
# set our API call parameters and filename before the first call
location = 'New York, NY 10009, New York, NY 10011 '
term = 'Pizza'

# %%
location.split(',')[0]
# Out:
# 'New York'

# %%
## Specify fodler for saving data

FOLDER ='Data/'

os.makedirs(FOLDER,exist_ok=True)

# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %% [markdown]
# # **Create Json File and Check For It**

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)

## If it does not exist: 
if file_exists ==False:
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder,exist_ok=True)
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE,'w')as f:
        json.dump([],f)
        
## If it exists, inform user
else:
       print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/New York-Pizza.json already exists.

# %% [markdown]
# # **Make First API Call On New York Restaurants**

# %%
# use our yelp_api variable's search_query method to perform our API call
results = yelp.search_query(term=term,location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 1700

# %%
results['region']
# Out:
# {'center': {'longitude': -73.99849891662598, 'latitude': 40.74036323966741}}

# %%
results['businesses']
# Out:
# [{'id': 't2Is1tWxGyZZ2nwg1kwAdg',
#   'alias': 'baggios-pizzeria-new-york',
#   'name': 'Baggios Pizzeria',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/H-uYIV2mp4Rv45YJKORs0g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/baggios-pizzeria-new-york?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 27,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.74215, 'longitude': -73.99737},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '162 7th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['162 7th Ave', 'New York, NY 10011']},
#   'phone': '+12123370505',
#   'display_phone': '(212) 337-0505',
#   'distance': 221.71866979213075},
#  {'id': 'G9hV4H2iGpWD8RoUpjtokg',
#   'alias': 'l-industrie-pizzeria-new-york',
#   'name': 'L’industrie Pizzeria',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Hzdlv1PI6ZM60HzVwxUc8A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-new-york?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 322,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.6,
#   'coordinates': {'latitude': 40.73323443774397, 'longitude': -74.0049081},
#   'transactions': [],
#   'location': {'address1': '104 Christopher St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['104 Christopher St', 'New York, NY 10014']},
#   'phone': '+12122560648',
#   'display_phone': '(212) 256-0648',
#   'distance': 959.140249745606},
#  {'id': '-9NO2IDCJMyNGZMAQ1-VQw',
#   'alias': 'ny-pizza-suprema-new-york',
#   'name': 'NY Pizza Suprema',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EqbDXneMuQP6pw6GemVdQA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ny-pizza-suprema-new-york?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 2682,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 40.7502059936523,
#    'longitude': -73.9953231811523},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '413 8th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['413 8th Ave', 'New York, NY 10001']},
#   'phone': '+12125948939',
#   'display_phone': '(212) 594-8939',
#   'distance': 1126.623533331627},
#  {'id': 'zj8Lq1T8KIC5zwFief15jg',
#   'alias': 'prince-street-pizza-new-york-2',
#   'name': 'Prince Street Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Jo9jBP5y6G_bG_g3H31fiw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 5346,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 40.72308755605564,
#    'longitude': -73.99453001177575},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '27 Prince St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['27 Prince St', 'New York, NY 10012']},
#   'phone': '+12129664100',
#   'display_phone': '(212) 966-4100',
#   'distance': 1949.8587485751177},
#  {'id': 'KEEXuHCYhsQJ-zpJhu98bA',
#   'alias': 'joes-pizza-new-york-148',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FluVgKezP5ifs7greHV8Qg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-new-york-148?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 2307,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.2,
#   'coordinates': {'latitude': 40.7547, 'longitude': -73.98696},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '1435 Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1435 Broadway', 'New York, NY 10018']},
#   'phone': '+16465594878',
#   'display_phone': '(646) 559-4878',
#   'distance': 1862.1791506414313},
#  {'id': 'S9S-uR_AvwZnUM3lfBTIwQ',
#   'alias': 'village-pizza-new-york',
#   'name': 'Village Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZqrlPUdCrijBVTpn8do2Eg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/village-pizza-new-york?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 163,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.8,
#   'coordinates': {'latitude': 40.73927, 'longitude': -74.00321},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '65 8th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['65 8th Ave', 'New York, NY 10014']},
#   'phone': '+12122434367',
#   'display_phone': '(212) 243-4367',
#   'distance': 413.5472441003511},
#  {'id': '2-GsvFaQpVpbaIdwb9lSeQ',
#   'alias': 'andiamo-pizza-new-york-2',
#   'name': 'Andiamo Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1p0cE3ZKgflstS6s__3fuQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/andiamo-pizza-new-york-2?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 212,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'catering', 'title': 'Caterers'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.746144, 'longitude': -73.990189},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '818 6th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['818 6th Ave', 'New York, NY 10001']},
#   'phone': '+12122542860',
#   'display_phone': '(212) 254-2860',
#   'distance': 948.996995937363},
#  {'id': 'OUJkCwzbtw16_KZAzYgE5w',
#   'alias': 'limelight-coal-brick-oven-pizzeria-new-york-6',
#   'name': 'Limelight Coal Brick Oven Pizzeria',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/50rm7o30L48PqmPPsD_IdQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/limelight-coal-brick-oven-pizzeria-new-york-6?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 857,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 3.6,
#   'coordinates': {'latitude': 40.74105844860242, 'longitude': -73.9936086},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '656 6th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10010',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['656 6th Ave', 'New York, NY 10010']},
#   'phone': '+16464845665',
#   'display_phone': '(646) 484-5665',
#   'distance': 419.1939965241047},
#  {'id': 'ypJRRRKZtaNad--1EbRBTg',
#   'alias': 'roma-pizza-and-restaurant-new-york',
#   'name': 'Roma Pizza & Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LA5DKU89rzsD41Hta-ECpg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/roma-pizza-and-restaurant-new-york?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 52,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'catering', 'title': 'Caterers'}],
#   'rating': 4.7,
#   'coordinates': {'latitude': 40.751211, 'longitude': -73.986364},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '980 6th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['980 6th Ave', 'New York, NY 10018']},
#   'phone': '+12124578555',
#   'display_phone': '(212) 457-8555',
#   'distance': 1580.255148075186},
#  {'id': 'LF1QAuvpfX7KGQlg2zMg6Q',
#   'alias': 'johns-of-bleecker-street-new-york-2',
#   'name': "John's of Bleecker Street",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Up7lhjRkQpl5PpmBQ0SFJQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/johns-of-bleecker-street-new-york-2?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 2836,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.2,
#   'coordinates': {'latitude': 40.73158, 'longitude': -74.00332},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '278 Bleecker St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['278 Bleecker St', 'New York, NY 10014']},
#   'phone': '+12122431680',
#   'display_phone': '(212) 243-1680',
#   'distance': 1057.9469461628844},
#  {'id': '16ZnHpuaaBt92XWeJHCC5A',
#   'alias': 'olio-e-più-new-york-7',
#   'name': 'Olio e Più',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CUpPgz_Q4QBHxxxxDJJTTA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/olio-e-pi%C3%B9-new-york-7?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 5775,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.73406231935954,
#    'longitude': -73.99999980859876},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3 Greenwich Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['3 Greenwich Ave', 'New York, NY 10014']},
#   'phone': '+12122436546',
#   'display_phone': '(212) 243-6546',
#   'distance': 711.9499925904423},
#  {'id': 'oJ_XSPZFpvIt6rvheSQl7A',
#   'alias': 'bleecker-street-pizza-new-york',
#   'name': 'Bleecker Street Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uScs5HVlHXaZMKIroDaHSg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bleecker-street-pizza-new-york?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 3116,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.2,
#   'coordinates': {'latitude': 40.7320627016512,
#    'longitude': -74.0036552270137},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '69 7th Ave S',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['69 7th Ave S', 'New York, NY 10014']},
#   'phone': '+12129244466',
#   'display_phone': '(212) 924-4466',
#   'distance': 996.3996114257127},
#  {'id': 'Nnbl4YIEHpuOnQj6zlK0UQ',
#   'alias': 'rosas-pizza-new-york-7',
#   'name': "Rosa's Pizza",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RPLJP7p2-BltCsruBXD5GQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rosas-pizza-new-york-7?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 7,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 40.74641219234452, 'longitude': -73.993616},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '299 7th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['299 7th Ave', 'New York, NY 10001']},
#   'phone': '+12127413560',
#   'display_phone': '(212) 741-3560',
#   'distance': 788.4337908151011},
#  {'id': 'H8qcX7MNNnC1bqE0LnIhKg',
#   'alias': 'simò-pizza-new-york-14',
#   'name': 'Simò Pizza',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Z5FXhqljOVfRaqQvDRqnRA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sim%C3%B2-pizza-new-york-14?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 263,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7392597584612,
#    'longitude': -74.0088130692187},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '90-92 Gansevoort St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['90-92 Gansevoort St', 'New York, NY 10014']},
#   'phone': '+12124622703',
#   'display_phone': '(212) 462-2703',
#   'distance': 877.5895337889477},
#  {'id': 'REC_m1Y4caJIXz8DDdgh-A',
#   'alias': 'mels-new-york-7',
#   'name': "Mel's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fqh1v4TE_qzXpRL0bFWv7A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mels-new-york-7?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 112,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 40.74303, 'longitude': -74.00779},
#   'transactions': [],
#   'location': {'address1': '85 10th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['85 10th Ave', 'New York, NY 10011']},
#   'phone': '+12129702202',
#   'display_phone': '(212) 970-2202',
#   'distance': 859.6166055144579},
#  {'id': 'JOvcJqD5eCFrGjFa6k7vpQ',
#   'alias': 'zia-maria-chelsea-new-york-2',
#   'name': 'Zia Maria - Chelsea',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/A2TFeyLpQ11MR563dsw0Dg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/zia-maria-chelsea-new-york-2?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 374,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.1,
#   'coordinates': {'latitude': 40.7454863, 'longitude': -73.9993392},
#   'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '318 W 23rd St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['318 W 23rd St', 'New York, NY 10011']},
#   'phone': '+12125249200',
#   'display_phone': '(212) 524-9200',
#   'distance': 564.8050635825302},
#  {'id': 'NG-vmMrBZlxAZrxgoiromg',
#   'alias': 'tappo-nycthincrust-pizza-new-york',
#   'name': 'TAPPO NYCThinCrust Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BAeAQxgnpVFwAs_ahdAT-A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tappo-nycthincrust-pizza-new-york?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 597,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.74337, 'longitude': -73.99153},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '49 W 24th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10010',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['49 W 24th St', 'New York, NY 10010']},
#   'phone': '+12128079200',
#   'display_phone': '(212) 807-9200',
#   'distance': 684.9647408461361},
#  {'id': 'afuiZyn9oOyyCpuW7wGfHQ',
#   'alias': 'l-antica-pizzeria-da-michele-new-york-2',
#   'name': 'L’Antica Pizzeria da Michele',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2zolmmCX9VhsR91-Tt7vjQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/l-antica-pizzeria-da-michele-new-york-2?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 149,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.2,
#   'coordinates': {'latitude': 40.737052, 'longitude': -74.001571},
#   'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#   'price': '$$$',
#   'location': {'address1': '2 Bank St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2 Bank St', 'New York, NY 10014']},
#   'phone': '+19295246682',
#   'display_phone': '(929) 524-6682',
#   'distance': 452.11709883507353},
#  {'id': 'f5VGuw9Fzb6P6E7oqSvjPw',
#   'alias': 'js-pizza-new-york',
#   'name': "J's Pizza",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CvY23nlLlCvh1BFK90RQ9Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/js-pizza-new-york?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 156,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.1,
#   'coordinates': {'latitude': 40.7398164, 'longitude': -73.9989453},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '98 7th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['98 7th Ave', 'New York, NY 10011']},
#   'phone': '+12129299003',
#   'display_phone': '(212) 929-9003',
#   'distance': 71.5798620037084},
#  {'id': '77q5bM4bXA63BqGwN-Cy2Q',
#   'alias': 'joes-pizza-new-york-110',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RaDxJoET3ysJUqyZh26kvA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-new-york-110?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 103,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 2.9,
#   'coordinates': {'latitude': 40.7439080906573,
#    'longitude': -73.9997112751007},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '211 8th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['211 8th Ave', 'New York, NY 10011']},
#   'phone': '+12122433226',
#   'display_phone': '(212) 243-3226',
#   'distance': 407.1871211787632}]

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                          alias  \
# 0   t2Is1tWxGyZZ2nwg1kwAdg                      baggios-pizzeria-new-york
# 1   G9hV4H2iGpWD8RoUpjtokg                  l-industrie-pizzeria-new-york
# 2   -9NO2IDCJMyNGZMAQ1-VQw                      ny-pizza-suprema-new-york
# 3   zj8Lq1T8KIC5zwFief15jg                 prince-street-pizza-new-york-2
# 4   KEEXuHCYhsQJ-zpJhu98bA                        joes-pizza-new-york-148
# 5   S9S-uR_AvwZnUM3lfBTIwQ                         village-pizza-new-york
# 6   2-GsvFaQpVpbaIdwb9lSeQ                       andiamo-pizza-new-york-2
# 7   OUJkCwzbtw16_KZAzYgE5w  limelight-coal-brick-oven-pizzeria-new-york-6
# 8   ypJRRRKZtaNad--1EbRBTg             roma-pizza-and-restaurant-new-york
# 9   LF1QAuvpfX7KGQlg2zMg6Q            johns-of-bleecker-street-new-york-2
# 10  16ZnHpuaaBt92XWeJHCC5A                          olio-e-più-new-york-7
# 11  oJ_XSPZFpvIt6rvheSQl7A                 bleecker-street-pizza-new-york
# 12  Nnbl4YIEHpuOnQj6zlK0UQ                         rosas-pizza-new-york-7
# 13  H8qcX7MNNnC1bqE0LnIhKg                         simò-pizza-new-york-14
# 14  REC_m1Y4caJIXz8DDdgh-A                                mels-new-york-7
# 15  JOvcJqD5eCFrGjFa6k7vpQ                   zia-maria-chelsea-new-york-2
# 16  NG-vmMrBZlxAZrxgoiromg              tappo-nycthincrust-pizza-new-york
# 17  afuiZyn9oOyyCpuW7wGfHQ        l-antica-pizzeria-da-michele-new-york-2
# 18  f5VGuw9Fzb6P6E7oqSvjPw                              js-pizza-new-york
# 19  77q5bM4bXA63BqGwN-Cy2Q                        joes-pizza-new-york-110
#
#                                   name  \
# 0                     Baggios Pizzeria
# 1                 L’industrie Pizzeria
# 2                     NY Pizza Suprema
# 3                  Prince Street Pizza
# 4                          Joe's Pizza
# 5                        Village Pizza
# 6                        Andiamo Pizza
# 7   Limelight Coal Brick Oven Pizzeria
# 8              Roma Pizza & Restaurant
# 9            John's of Bleecker Street
# 10                          Olio e Più
# 11               Bleecker Street Pizza
# 12                        Rosa's Pizza
# 13                          Simò Pizza
# 14                               Mel's
# 15                 Zia Maria - Chelsea
# 16            TAPPO NYCThinCrust Pizza
# 17        L’Antica Pizzeria da Michele
# 18                           J's Pizza
# 19                         Joe's Pizza
#
#                                             image_url  is_closed  \
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/H-uYIV...      False
# 1   https://s3-media4.fl.yelpcdn.com/bphoto/Hzdlv1...      False
# 2   https://s3-media4.fl.yelpcdn.com/bphoto/EqbDXn...      False
# 3   https://s3-media1.fl.yelpcdn.com/bphoto/Jo9jBP...      False
# 4   https://s3-media4.fl.yelpcdn.com/bphoto/FluVgK...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/ZqrlPU...      False
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/1p0cE3...      False
# 7   https://s3-media3.fl.yelpcdn.com/bphoto/50rm7o...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/LA5DKU...      False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/Up7lhj...      False
# 10  https://s3-media4.fl.yelpcdn.com/bphoto/CUpPgz...      False
# 11  https://s3-media1.fl.yelpcdn.com/bphoto/uScs5H...      False
# 12  https://s3-media1.fl.yelpcdn.com/bphoto/RPLJP7...      False
# 13  https://s3-media4.fl.yelpcdn.com/bphoto/Z5FXhq...      False
# 14  https://s3-media2.fl.yelpcdn.com/bphoto/fqh1v4...      False
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/A2TFey...      False
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/BAeAQx...      False
# 17  https://s3-media3.fl.yelpcdn.com/bphoto/2zolmm...      False
# 18  https://s3-media2.fl.yelpcdn.com/bphoto/CvY23n...      False
# 19  https://s3-media4.fl.yelpcdn.com/bphoto/RaDxJo...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/baggios-pizzeria-new-...            27
# 1   https://www.yelp.com/biz/l-industrie-pizzeria-...           322
# 2   https://www.yelp.com/biz/ny-pizza-suprema-new-...          2682
# 3   https://www.yelp.com/biz/prince-street-pizza-n...          5346
# 4   https://www.yelp.com/biz/joes-pizza-new-york-1...          2307
# 5   https://www.yelp.com/biz/village-pizza-new-yor...           163
# 6   https://www.yelp.com/biz/andiamo-pizza-new-yor...           212
# 7   https://www.yelp.com/biz/limelight-coal-brick-...           857
# 8   https://www.yelp.com/biz/roma-pizza-and-restau...            52
# 9   https://www.yelp.com/biz/johns-of-bleecker-str...          2836
# 10  https://www.yelp.com/biz/olio-e-pi%C3%B9-new-y...          5775
# 11  https://www.yelp.com/biz/bleecker-street-pizza...          3116
# 12  https://www.yelp.com/biz/rosas-pizza-new-york-...             7
# 13  https://www.yelp.com/biz/sim%C3%B2-pizza-new-y...           263
# 14  https://www.yelp.com/biz/mels-new-york-7?adjus...           112
# 15  https://www.yelp.com/biz/zia-maria-chelsea-new...           374
# 16  https://www.yelp.com/biz/tappo-nycthincrust-pi...           597
# 17  https://www.yelp.com/biz/l-antica-pizzeria-da-...           149
# 18  https://www.yelp.com/biz/js-pizza-new-york?adj...           156
# 19  https://www.yelp.com/biz/joes-pizza-new-york-1...           103
#
#                                            categories  rating  \
# 0   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 1              [{'alias': 'pizza', 'title': 'Pizza'}]     4.6
# 2              [{'alias': 'pizza', 'title': 'Pizza'}]     4.3
# 3   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.3
# 4              [{'alias': 'pizza', 'title': 'Pizza'}]     4.2
# 5              [{'alias': 'pizza', 'title': 'Pizza'}]     3.8
# 6   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 7   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.6
# 8   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.7
# 9              [{'alias': 'pizza', 'title': 'Pizza'}]     4.2
# 10  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 11  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.2
# 12  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.3
# 13  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 14  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.4
# 15  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.1
# 16  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 17  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.2
# 18             [{'alias': 'pizza', 'title': 'Pizza'}]     4.1
# 19             [{'alias': 'pizza', 'title': 'Pizza'}]     2.9
#
#                                           coordinates  \
# 0      {'latitude': 40.74215, 'longitude': -73.99737}
# 1   {'latitude': 40.73323443774397, 'longitude': -...
# 2   {'latitude': 40.7502059936523, 'longitude': -7...
# 3   {'latitude': 40.72308755605564, 'longitude': -...
# 4       {'latitude': 40.7547, 'longitude': -73.98696}
# 5      {'latitude': 40.73927, 'longitude': -74.00321}
# 6    {'latitude': 40.746144, 'longitude': -73.990189}
# 7   {'latitude': 40.74105844860242, 'longitude': -...
# 8    {'latitude': 40.751211, 'longitude': -73.986364}
# 9      {'latitude': 40.73158, 'longitude': -74.00332}
# 10  {'latitude': 40.73406231935954, 'longitude': -...
# 11  {'latitude': 40.7320627016512, 'longitude': -7...
# 12  {'latitude': 40.74641219234452, 'longitude': -...
# 13  {'latitude': 40.7392597584612, 'longitude': -7...
# 14     {'latitude': 40.74303, 'longitude': -74.00779}
# 15  {'latitude': 40.7454863, 'longitude': -73.9993...
# 16     {'latitude': 40.74337, 'longitude': -73.99153}
# 17   {'latitude': 40.737052, 'longitude': -74.001571}
# 18  {'latitude': 40.7398164, 'longitude': -73.9989...
# 19  {'latitude': 40.7439080906573, 'longitude': -7...
#
#                                   transactions  \
# 0                           [pickup, delivery]
# 1                                           []
# 2                           [pickup, delivery]
# 3                           [pickup, delivery]
# 4                           [pickup, delivery]
# 5                           [pickup, delivery]
# 6                           [pickup, delivery]
# 7                           [delivery, pickup]
# 8                           [pickup, delivery]
# 9                           [pickup, delivery]
# 10                          [pickup, delivery]
# 11                          [pickup, delivery]
# 12                          [pickup, delivery]
# 13                          [pickup, delivery]
# 14                                          []
# 15  [pickup, delivery, restaurant_reservation]
# 16                          [pickup, delivery]
# 17  [delivery, pickup, restaurant_reservation]
# 18                          [pickup, delivery]
# 19                          [pickup, delivery]
#
#                                              location         phone  \
# 0   {'address1': '162 7th Ave', 'address2': '', 'a...  +12123370505
# 1   {'address1': '104 Christopher St', 'address2':...  +12122560648
# 2   {'address1': '413 8th Ave', 'address2': '', 'a...  +12125948939
# 3   {'address1': '27 Prince St', 'address2': None,...  +12129664100
# 4   {'address1': '1435 Broadway', 'address2': '', ...  +16465594878
# 5   {'address1': '65 8th Ave', 'address2': '', 'ad...  +12122434367
# 6   {'address1': '818 6th Ave', 'address2': None, ...  +12122542860
# 7   {'address1': '656 6th Ave', 'address2': '', 'a...  +16464845665
# 8   {'address1': '980 6th Ave', 'address2': None, ...  +12124578555
# 9   {'address1': '278 Bleecker St', 'address2': ''...  +12122431680
# 10  {'address1': '3 Greenwich Ave', 'address2': No...  +12122436546
# 11  {'address1': '69 7th Ave S', 'address2': None,...  +12129244466
# 12  {'address1': '299 7th Ave', 'address2': '', 'a...  +12127413560
# 13  {'address1': '90-92 Gansevoort St', 'address2'...  +12124622703
# 14  {'address1': '85 10th Ave', 'address2': '', 'a...  +12129702202
# 15  {'address1': '318 W 23rd St', 'address2': '', ...  +12125249200
# 16  {'address1': '49 W 24th St', 'address2': '', '...  +12128079200
# 17  {'address1': '2 Bank St', 'address2': None, 'a...  +19295246682
# 18  {'address1': '98 7th Ave', 'address2': '', 'ad...  +12129299003
# 19  {'address1': '211 8th Ave', 'address2': '', 'a...  +12122433226
#
#      display_phone     distance price
# 0   (212) 337-0505   221.718670   NaN
# 1   (212) 256-0648   959.140250   NaN
# 2   (212) 594-8939  1126.623533    $$
# 3   (212) 966-4100  1949.858749     $
# 4   (646) 559-4878  1862.179151     $
# 5   (212) 243-4367   413.547244     $
# 6   (212) 254-2860   948.996996   NaN
# 7   (646) 484-5665   419.193997    $$
# 8   (212) 457-8555  1580.255148   NaN
# 9   (212) 243-1680  1057.946946    $$
# 10  (212) 243-6546   711.949993    $$
# 11  (212) 924-4466   996.399611     $
# 12  (212) 741-3560   788.433791   NaN
# 13  (212) 462-2703   877.589534    $$
# 14  (212) 970-2202   859.616606   NaN
# 15  (212) 524-9200   564.805064    $$
# 16  (212) 807-9200   684.964741    $$
# 17  (929) 524-6682   452.117099   $$$
# 18  (212) 929-9003    71.579862     $
# 19  (212) 243-3226   407.187121     $

# %% [markdown]
# # **Check Results**

# %%
# How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 85

# %% [markdown]
# # **Data Cleaning**

# %%
# Converting the JSON file to a dataframe
nydf = pd.DataFrame(results['businesses'])

# %%
nydf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             20 non-null     object
#  1   alias          20 non-null     object
#  2   name           20 non-null     object
#  3   image_url      20 non-null     object
#  4   is_closed      20 non-null     bool
#  5   url            20 non-null     object
#  6   review_count   20 non-null     int64
#  7   categories     20 non-null     object
#  8   rating         20 non-null     float64
#  9   coordinates    20 non-null     object
#  10  transactions   20 non-null     object
#  11  location       20 non-null     object
#  12  phone          20 non-null     object
#  13  display_phone  20 non-null     object
#  14  distance       20 non-null     float64
#  15  price          14 non-null     object
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 2.5+ KB

# %%
nydf.head()
# Out:
#                        id                           alias  \
# 0  t2Is1tWxGyZZ2nwg1kwAdg       baggios-pizzeria-new-york
# 1  G9hV4H2iGpWD8RoUpjtokg   l-industrie-pizzeria-new-york
# 2  -9NO2IDCJMyNGZMAQ1-VQw       ny-pizza-suprema-new-york
# 3  zj8Lq1T8KIC5zwFief15jg  prince-street-pizza-new-york-2
# 4  KEEXuHCYhsQJ-zpJhu98bA         joes-pizza-new-york-148
#
#                    name                                          image_url  \
# 0      Baggios Pizzeria  https://s3-media3.fl.yelpcdn.com/bphoto/H-uYIV...
# 1  L’industrie Pizzeria  https://s3-media4.fl.yelpcdn.com/bphoto/Hzdlv1...
# 2      NY Pizza Suprema  https://s3-media4.fl.yelpcdn.com/bphoto/EqbDXn...
# 3   Prince Street Pizza  https://s3-media1.fl.yelpcdn.com/bphoto/Jo9jBP...
# 4           Joe's Pizza  https://s3-media4.fl.yelpcdn.com/bphoto/FluVgK...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/baggios-pizzeria-new-...            27
# 1      False  https://www.yelp.com/biz/l-industrie-pizzeria-...           322
# 2      False  https://www.yelp.com/biz/ny-pizza-suprema-new-...          2682
# 3      False  https://www.yelp.com/biz/prince-street-pizza-n...          5346
# 4      False  https://www.yelp.com/biz/joes-pizza-new-york-1...          2307
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 1             [{'alias': 'pizza', 'title': 'Pizza'}]     4.6
# 2             [{'alias': 'pizza', 'title': 'Pizza'}]     4.3
# 3  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.3
# 4             [{'alias': 'pizza', 'title': 'Pizza'}]     4.2
#
#                                          coordinates        transactions  \
# 0     {'latitude': 40.74215, 'longitude': -73.99737}  [pickup, delivery]
# 1  {'latitude': 40.73323443774397, 'longitude': -...                  []
# 2  {'latitude': 40.7502059936523, 'longitude': -7...  [pickup, delivery]
# 3  {'latitude': 40.72308755605564, 'longitude': -...  [pickup, delivery]
# 4      {'latitude': 40.7547, 'longitude': -73.98696}  [pickup, delivery]
#
#                                             location         phone  \
# 0  {'address1': '162 7th Ave', 'address2': '', 'a...  +12123370505
# 1  {'address1': '104 Christopher St', 'address2':...  +12122560648
# 2  {'address1': '413 8th Ave', 'address2': '', 'a...  +12125948939
# 3  {'address1': '27 Prince St', 'address2': None,...  +12129664100
# 4  {'address1': '1435 Broadway', 'address2': '', ...  +16465594878
#
#     display_phone     distance price
# 0  (212) 337-0505   221.718670   NaN
# 1  (212) 256-0648   959.140250   NaN
# 2  (212) 594-8939  1126.623533    $$
# 3  (212) 966-4100  1949.858749     $
# 4  (646) 559-4878  1862.179151     $
