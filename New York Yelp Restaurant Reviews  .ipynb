# %% [markdown]
# # **New York Restaurant Reviews**

# %% [markdown]
# ## **Imports**

# %%
# Imports 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports 
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# # **Load Credentials and Create Yelp API Object**

# %%
# Load API Credentials:
with open("F:\\Desktop Backup\\talen\\.secret\\yelp_api.json",'r') as f:
    login = json.load(f)

# %%
# Show Login Keys:
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'],timeout_s=5.0)

# %%
# set our API call parameters and filename before the first call
location = 'Brooklyn, NY 11211 '
term = 'Pizza'

# %%
location.split(',')[0]
# Out:
# 'Brooklyn'

# %%
## Specify fodler for saving data

FOLDER ='Data/'

os.makedirs(FOLDER,exist_ok=True)

# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %% [markdown]
# ## **Create Json File and Check for It.**

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)

## If it does not exist: 
if file_exists ==False:
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder,exist_ok=True)
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE,'w')as f:
        json.dump([],f)
        
## If it exists, inform user
else:
       print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Brooklyn-Pizza.json already exists.

# %% [markdown]
# # **Make the first API call on New York Restaurants**

# %%
# use our yelp_api variable's search_query method to perform our API call
results = yelp.search_query(term=term,location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 6200

# %%
results['region']
# Out:
# {'center': {'longitude': -73.94966125488281, 'latitude': 40.71264321986641}}

# %%
results['businesses']
# Out:
# [{'id': 'v1DHGRNCH9247WLYoaoA9A',
#   'alias': 'l-industrie-pizzeria-brooklyn',
#   'name': "L'industrie Pizzeria",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1-VBwAOj0g9YKYey3V-Z6Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 1368,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.7,
#   'coordinates': {'latitude': 40.71162, 'longitude': -73.95783},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '254 S 2nd St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['254 S 2nd St', 'Brooklyn, NY 11211']},
#   'phone': '+17185990002',
#   'display_phone': '(718) 599-0002',
#   'distance': 701.8952662330755},
#  {'id': 'ON7ihGoWgZaBFDaLCYpk2Q',
#   'alias': 'rome-to-brooklyn-pizza-brooklyn-2',
#   'name': 'Rome To Brooklyn Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4JavGLx9XtaLrrNzj36Vjg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rome-to-brooklyn-pizza-brooklyn-2?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 185,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.8,
#   'coordinates': {'latitude': 40.711886016839244, 'longitude': -73.9429006},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '755 Grand St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['755 Grand St', 'Brooklyn, NY 11211']},
#   'phone': '+17182693239',
#   'display_phone': '(718) 269-3239',
#   'distance': 576.0092018985303},
#  {'id': 'r1PWMTbFXBmEhi0scGPf3w',
#   'alias': 'aces-pizza-brooklyn',
#   'name': "Ace's Pizza",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/id-UXjLag2J47O_JkICU6A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/aces-pizza-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 212,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#   'rating': 4.7,
#   'coordinates': {'latitude': 40.71505, 'longitude': -73.958365},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '637 Driggs Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['637 Driggs Ave', 'Brooklyn, NY 11211']},
#   'phone': '+13477254366',
#   'display_phone': '(347) 725-4366',
#   'distance': 782.179585946517},
#  {'id': 'pGr5QuQU7Ur5GHLvXbT8bw',
#   'alias': 'paulie-gees-brooklyn',
#   'name': "Paulie Gee's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BgnKLCGphnQw_8jrltMlHA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/paulie-gees-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 1390,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 40.72955, 'longitude': -73.95857},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '60 Greenpoint Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['60 Greenpoint Ave', 'Brooklyn, NY 11222']},
#   'phone': '+13479873747',
#   'display_phone': '(347) 987-3747',
#   'distance': 2024.1199062451194},
#  {'id': 'WE_dce2JKcv-VoFNaqiJ4w',
#   'alias': 'carmines-pizzeria-brooklyn',
#   'name': "Carmine's Pizzeria",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ifwMwKV2JhREjjUFRg3qUA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/carmines-pizzeria-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 563,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.714987, 'longitude': -73.94414},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '358 Graham Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['358 Graham Ave', 'Brooklyn, NY 11211']},
#   'phone': '+17187829659',
#   'display_phone': '(718) 782-9659',
#   'distance': 530.7604975886186},
#  {'id': 'FhXjAc6nKLf414KxYujUHw',
#   'alias': 'robertas-brooklyn-2',
#   'name': "Roberta's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/e8enpWJ_fWrFXMNxhACfQQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/robertas-brooklyn-2?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 3352,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.70493, 'longitude': -73.93399},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '261 Moore St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11206',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['261 Moore St', 'Brooklyn, NY 11206']},
#   'phone': '+17184171118',
#   'display_phone': '(718) 417-1118',
#   'distance': 1574.938853168854},
#  {'id': '2FgUndzCT_jJATbmrBDVBg',
#   'alias': 'paulie-gees-slice-shop-brooklyn',
#   'name': "Paulie Gee's Slice Shop",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zhWAAjTRTZ1PdQW-JNV69g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/paulie-gees-slice-shop-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 414,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72836, 'longitude': -73.9572},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '110 Franklin St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['110 Franklin St', 'Brooklyn, NY 11222']},
#   'phone': '+19293376384',
#   'display_phone': '(929) 337-6384',
#   'distance': 1859.2440542825516},
#  {'id': 'LO2kgBEQZJ-ceFbj6-UaEA',
#   'alias': 'mos-general-pizza-and-provisions-brooklyn',
#   'name': "Mo's General Pizza & Provisions",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cIYsGoJtwXp-uf5Kn_aG_w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mos-general-pizza-and-provisions-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 57,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 40.71562045514015, 'longitude': -73.9494481},
#   'transactions': [],
#   'location': {'address1': '620 Lorimer St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['620 Lorimer St', 'Brooklyn, NY 11211']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 331.5401933984459},
#  {'id': 'tpcCX_SHaNXqAzXOzbluJQ',
#   'alias': 'fini-pizza-brooklyn',
#   'name': 'Fini Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/harcCpQXJDORLLW0BFQNfw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fini-pizza-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 168,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 40.71348, 'longitude': -73.96182},
#   'transactions': [],
#   'location': {'address1': '305 Bedford Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['305 Bedford Ave', 'Brooklyn, NY 11211']},
#   'phone': '+19299693073',
#   'display_phone': '(929) 969-3073',
#   'distance': 1022.7361253733266},
#  {'id': 'CFR-HzVHKWRMpMAR3LAhzg',
#   'alias': 'montesacro-pinseria-brooklyn-brooklyn',
#   'name': 'Montesacro Pinseria Brooklyn',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/A9l8TN1c_w9KN-PFjlXtZA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/montesacro-pinseria-brooklyn-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 295,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 40.71338, 'longitude': -73.95136},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '432 Union Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['432 Union Ave', 'Brooklyn, NY 11211']},
#   'phone': '+13479161062',
#   'display_phone': '(347) 916-1062',
#   'distance': 149.08787907869174},
#  {'id': 'G77Q6kU-7qRefColCRTS0w',
#   'alias': 'robertas-brooklyn-5',
#   'name': "Roberta's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/naIec6omkhoRe6JWRFm8JQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/robertas-brooklyn-5?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 123,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.9,
#   'coordinates': {'latitude': 40.71618788546057,
#    'longitude': -73.96651754323669},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '6 Grand St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['6 Grand St', 'Brooklyn, NY 11249']},
#   'phone': '+17182782400',
#   'display_phone': '(718) 278-2400',
#   'distance': 1474.3494499312937},
#  {'id': 'GRXvvB1OKMuW4XDWEaVAlg',
#   'alias': 'joes-pizza-brooklyn-8',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0WEXB_9LUY86MTKnc2UXug/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-brooklyn-8?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 487,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7168952, 'longitude': -73.95892996733771},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '216 Bedford Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['216 Bedford Ave', 'Brooklyn, NY 11249']},
#   'phone': '+17183882216',
#   'display_phone': '(718) 388-2216',
#   'distance': 913.1197256251238},
#  {'id': 'xv1Tdb7FhGBbySNfIt9pGQ',
#   'alias': 'williamsburg-pizza-brooklyn-6',
#   'name': 'Williamsburg Pizza',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WsjRUp8lZ26o-vCXiUzFOg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/williamsburg-pizza-brooklyn-6?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 378,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.3,
#   'coordinates': {'latitude': 40.7078768, 'longitude': -73.9507711},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '265 Union Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['265 Union Ave', 'Brooklyn, NY 11211']},
#   'phone': '+17188558729',
#   'display_phone': '(718) 855-8729',
#   'distance': 517.8448028552828},
#  {'id': 'aPn2_EtjfHduXEmEBNxuFA',
#   'alias': 'rosas-pizza-brooklyn',
#   'name': "Rosa's Pizza",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TtcGEKqRXYjkxNalZYapTA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rosas-pizza-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 211,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.2,
#   'coordinates': {'latitude': 40.7139499, 'longitude': -73.95563},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '374 Metropolitan Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['374 Metropolitan Ave', 'Brooklyn, NY 11211']},
#   'phone': '+17189632378',
#   'display_phone': '(718) 963-2378',
#   'distance': 529.9638919970739},
#  {'id': 'fg9VsI2rxjAHcGrvk0DDsQ',
#   'alias': 'greenpoint-original-italian-pizza-brooklyn',
#   'name': 'Greenpoint Original Italian Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/REEkEGB7vnQja5pOtOSDsQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/greenpoint-original-italian-pizza-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 41,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 40.7256746906384,
#    'longitude': -73.9513858978921},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '93 Norman Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['93 Norman Ave', 'Brooklyn, NY 11222']},
#   'phone': '+19179091819',
#   'display_phone': '(917) 909-1819',
#   'distance': 1456.303155395669},
#  {'id': 'ozYKGhJoGkQbFGskBeONuw',
#   'alias': 'the-original-square-of-soho-brooklyn',
#   'name': 'The Original Square Of Soho',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SlMVxJ6UCNf6ahRJHDz_NQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-original-square-of-soho-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 23,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 40.70740304957788,
#    'longitude': -73.93186589137349},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '2 Knickerbocker Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#   'phone': '+13474220194',
#   'display_phone': '(347) 422-0194',
#   'distance': 1609.135716699237},
#  {'id': 'RqRCx09k0PZ4sZJgOxbAIA',
#   'alias': 'dough-vale-new-york',
#   'name': 'Dough Vale',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IUKwDlCnFx1-brvwmOjn_Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dough-vale-new-york?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 118,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.70933, 'longitude': -73.95407},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '330 S 3rd St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['330 S 3rd St', 'New York, NY 11211']},
#   'phone': '+13478897400',
#   'display_phone': '(347) 889-7400',
#   'distance': 535.4265025680102},
#  {'id': 'ysqgdbSrezXgVwER2kQWKA',
#   'alias': 'julianas-brooklyn-3',
#   'name': "Juliana's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/od36nFW220aMFAnNP00ocw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/julianas-brooklyn-3?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 2800,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 40.70274718768062,
#    'longitude': -73.99343490196397},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '19 Old Fulton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#   'phone': '+17185966700',
#   'display_phone': '(718) 596-6700',
#   'distance': 3850.308194886269},
#  {'id': 'iW11zKNq2gDylgAkKAfqCg',
#   'alias': 'salsa-pizzeria-brooklyn',
#   'name': 'Salsa Pizzeria',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ssjYUXaAYEZuw2fYqA12zg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/salsa-pizzeria-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 35,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7269007, 'longitude': -73.9554019},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '40 Clifford Pl',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['40 Clifford Pl', 'Brooklyn, NY 11222']},
#   'phone': '+13475424680',
#   'display_phone': '(347) 542-4680',
#   'distance': 1605.0887501314692},
#  {'id': 'EsHcyOLHaK76bQuU7bwiTw',
#   'alias': 'tonys-pizzeria-and-restaurant-brooklyn-3',
#   'name': "Tony's Pizzeria & Restaurant",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/viqI7JzZtEW4qFW_JmpF0w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tonys-pizzeria-and-restaurant-brooklyn-3?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 376,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 40.699286, 'longitude': -73.918724},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '443 Knickerbocker Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['443 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#   'phone': '+17184559664',
#   'display_phone': '(718) 455-9664',
#   'distance': 3001.095678100864}]

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                       alias  \
# 0   v1DHGRNCH9247WLYoaoA9A               l-industrie-pizzeria-brooklyn
# 1   ON7ihGoWgZaBFDaLCYpk2Q           rome-to-brooklyn-pizza-brooklyn-2
# 2   r1PWMTbFXBmEhi0scGPf3w                         aces-pizza-brooklyn
# 3   pGr5QuQU7Ur5GHLvXbT8bw                        paulie-gees-brooklyn
# 4   WE_dce2JKcv-VoFNaqiJ4w                  carmines-pizzeria-brooklyn
# 5   FhXjAc6nKLf414KxYujUHw                         robertas-brooklyn-2
# 6   2FgUndzCT_jJATbmrBDVBg             paulie-gees-slice-shop-brooklyn
# 7   LO2kgBEQZJ-ceFbj6-UaEA   mos-general-pizza-and-provisions-brooklyn
# 8   tpcCX_SHaNXqAzXOzbluJQ                         fini-pizza-brooklyn
# 9   CFR-HzVHKWRMpMAR3LAhzg       montesacro-pinseria-brooklyn-brooklyn
# 10  G77Q6kU-7qRefColCRTS0w                         robertas-brooklyn-5
# 11  GRXvvB1OKMuW4XDWEaVAlg                       joes-pizza-brooklyn-8
# 12  xv1Tdb7FhGBbySNfIt9pGQ               williamsburg-pizza-brooklyn-6
# 13  aPn2_EtjfHduXEmEBNxuFA                        rosas-pizza-brooklyn
# 14  fg9VsI2rxjAHcGrvk0DDsQ  greenpoint-original-italian-pizza-brooklyn
# 15  ozYKGhJoGkQbFGskBeONuw        the-original-square-of-soho-brooklyn
# 16  RqRCx09k0PZ4sZJgOxbAIA                         dough-vale-new-york
# 17  ysqgdbSrezXgVwER2kQWKA                         julianas-brooklyn-3
# 18  iW11zKNq2gDylgAkKAfqCg                     salsa-pizzeria-brooklyn
# 19  EsHcyOLHaK76bQuU7bwiTw    tonys-pizzeria-and-restaurant-brooklyn-3
#
#                                  name  \
# 0                L'industrie Pizzeria
# 1              Rome To Brooklyn Pizza
# 2                         Ace's Pizza
# 3                        Paulie Gee's
# 4                  Carmine's Pizzeria
# 5                           Roberta's
# 6             Paulie Gee's Slice Shop
# 7     Mo's General Pizza & Provisions
# 8                          Fini Pizza
# 9        Montesacro Pinseria Brooklyn
# 10                          Roberta's
# 11                        Joe's Pizza
# 12                 Williamsburg Pizza
# 13                       Rosa's Pizza
# 14  Greenpoint Original Italian Pizza
# 15        The Original Square Of Soho
# 16                         Dough Vale
# 17                          Juliana's
# 18                     Salsa Pizzeria
# 19       Tony's Pizzeria & Restaurant
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/1-VBwA...      False
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/4JavGL...      False
# 2   https://s3-media2.fl.yelpcdn.com/bphoto/id-UXj...      False
# 3   https://s3-media2.fl.yelpcdn.com/bphoto/BgnKLC...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/ifwMwK...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/e8enpW...      False
# 6   https://s3-media1.fl.yelpcdn.com/bphoto/zhWAAj...      False
# 7   https://s3-media4.fl.yelpcdn.com/bphoto/cIYsGo...      False
# 8   https://s3-media1.fl.yelpcdn.com/bphoto/harcCp...      False
# 9   https://s3-media3.fl.yelpcdn.com/bphoto/A9l8TN...      False
# 10  https://s3-media2.fl.yelpcdn.com/bphoto/naIec6...      False
# 11  https://s3-media3.fl.yelpcdn.com/bphoto/0WEXB_...      False
# 12  https://s3-media4.fl.yelpcdn.com/bphoto/WsjRUp...      False
# 13  https://s3-media4.fl.yelpcdn.com/bphoto/TtcGEK...      False
# 14  https://s3-media3.fl.yelpcdn.com/bphoto/REEkEG...      False
# 15  https://s3-media4.fl.yelpcdn.com/bphoto/SlMVxJ...      False
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/IUKwDl...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/od36nF...      False
# 18  https://s3-media3.fl.yelpcdn.com/bphoto/ssjYUX...      False
# 19  https://s3-media3.fl.yelpcdn.com/bphoto/viqI7J...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/l-industrie-pizzeria-...          1368
# 1   https://www.yelp.com/biz/rome-to-brooklyn-pizz...           185
# 2   https://www.yelp.com/biz/aces-pizza-brooklyn?a...           212
# 3   https://www.yelp.com/biz/paulie-gees-brooklyn?...          1390
# 4   https://www.yelp.com/biz/carmines-pizzeria-bro...           563
# 5   https://www.yelp.com/biz/robertas-brooklyn-2?a...          3352
# 6   https://www.yelp.com/biz/paulie-gees-slice-sho...           414
# 7   https://www.yelp.com/biz/mos-general-pizza-and...            57
# 8   https://www.yelp.com/biz/fini-pizza-brooklyn?a...           168
# 9   https://www.yelp.com/biz/montesacro-pinseria-b...           295
# 10  https://www.yelp.com/biz/robertas-brooklyn-5?a...           123
# 11  https://www.yelp.com/biz/joes-pizza-brooklyn-8...           487
# 12  https://www.yelp.com/biz/williamsburg-pizza-br...           378
# 13  https://www.yelp.com/biz/rosas-pizza-brooklyn?...           211
# 14  https://www.yelp.com/biz/greenpoint-original-i...            41
# 15  https://www.yelp.com/biz/the-original-square-o...            23
# 16  https://www.yelp.com/biz/dough-vale-new-york?a...           118
# 17  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2800
# 18  https://www.yelp.com/biz/salsa-pizzeria-brookl...            35
# 19  https://www.yelp.com/biz/tonys-pizzeria-and-re...           376
#
#                                            categories  rating  \
# 0              [{'alias': 'pizza', 'title': 'Pizza'}]     4.7
# 1   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.8
# 2   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.7
# 3              [{'alias': 'pizza', 'title': 'Pizza'}]     4.3
# 4   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 5   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 6   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 7              [{'alias': 'pizza', 'title': 'Pizza'}]     4.4
# 8              [{'alias': 'pizza', 'title': 'Pizza'}]     4.3
# 9   [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.4
# 10             [{'alias': 'pizza', 'title': 'Pizza'}]     3.9
# 11             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 12             [{'alias': 'pizza', 'title': 'Pizza'}]     3.3
# 13  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.2
# 14             [{'alias': 'pizza', 'title': 'Pizza'}]     4.4
# 15             [{'alias': 'pizza', 'title': 'Pizza'}]     4.4
# 16  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 17             [{'alias': 'pizza', 'title': 'Pizza'}]     4.4
# 18  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 19  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.4
#
#                                           coordinates        transactions  \
# 0      {'latitude': 40.71162, 'longitude': -73.95783}          [delivery]
# 1   {'latitude': 40.711886016839244, 'longitude': ...  [delivery, pickup]
# 2     {'latitude': 40.71505, 'longitude': -73.958365}  [delivery, pickup]
# 3      {'latitude': 40.72955, 'longitude': -73.95857}            [pickup]
# 4     {'latitude': 40.714987, 'longitude': -73.94414}  [delivery, pickup]
# 5      {'latitude': 40.70493, 'longitude': -73.93399}  [delivery, pickup]
# 6       {'latitude': 40.72836, 'longitude': -73.9572}          [delivery]
# 7   {'latitude': 40.71562045514015, 'longitude': -...                  []
# 8      {'latitude': 40.71348, 'longitude': -73.96182}                  []
# 9      {'latitude': 40.71338, 'longitude': -73.95136}  [delivery, pickup]
# 10  {'latitude': 40.71618788546057, 'longitude': -...  [delivery, pickup]
# 11  {'latitude': 40.7168952, 'longitude': -73.9589...  [delivery, pickup]
# 12  {'latitude': 40.7078768, 'longitude': -73.9507...  [delivery, pickup]
# 13   {'latitude': 40.7139499, 'longitude': -73.95563}  [delivery, pickup]
# 14  {'latitude': 40.7256746906384, 'longitude': -7...  [delivery, pickup]
# 15  {'latitude': 40.70740304957788, 'longitude': -...  [delivery, pickup]
# 16     {'latitude': 40.70933, 'longitude': -73.95407}  [delivery, pickup]
# 17  {'latitude': 40.70274718768062, 'longitude': -...          [delivery]
# 18  {'latitude': 40.7269007, 'longitude': -73.9554...  [delivery, pickup]
# 19   {'latitude': 40.699286, 'longitude': -73.918724}  [delivery, pickup]
#
#    price                                           location         phone  \
# 0     $$  {'address1': '254 S 2nd St', 'address2': '', '...  +17185990002
# 1    NaN  {'address1': '755 Grand St', 'address2': None,...  +17182693239
# 2     $$  {'address1': '637 Driggs Ave', 'address2': '',...  +13477254366
# 3     $$  {'address1': '60 Greenpoint Ave', 'address2': ...  +13479873747
# 4     $$  {'address1': '358 Graham Ave', 'address2': '',...  +17187829659
# 5     $$  {'address1': '261 Moore St', 'address2': '', '...  +17184171118
# 6      $  {'address1': '110 Franklin St', 'address2': ''...  +19293376384
# 7    NaN  {'address1': '620 Lorimer St', 'address2': '',...
# 8    NaN  {'address1': '305 Bedford Ave', 'address2': ''...  +19299693073
# 9     $$  {'address1': '432 Union Ave', 'address2': None...  +13479161062
# 10   NaN  {'address1': '6 Grand St', 'address2': '', 'ad...  +17182782400
# 11    $$  {'address1': '216 Bedford Ave', 'address2': ''...  +17183882216
# 12     $  {'address1': '265 Union Ave', 'address2': '', ...  +17188558729
# 13     $  {'address1': '374 Metropolitan Ave', 'address2...  +17189632378
# 14   NaN  {'address1': '93 Norman Ave', 'address2': '', ...  +19179091819
# 15   NaN  {'address1': '2 Knickerbocker Ave', 'address2'...  +13474220194
# 16    $$  {'address1': '330 S 3rd St', 'address2': None,...  +13478897400
# 17    $$  {'address1': '19 Old Fulton St', 'address2': '...  +17185966700
# 18   NaN  {'address1': '40 Clifford Pl', 'address2': '',...  +13475424680
# 19     $  {'address1': '443 Knickerbocker Ave', 'address...  +17184559664
#
#      display_phone     distance
# 0   (718) 599-0002   701.895266
# 1   (718) 269-3239   576.009202
# 2   (347) 725-4366   782.179586
# 3   (347) 987-3747  2024.119906
# 4   (718) 782-9659   530.760498
# 5   (718) 417-1118  1574.938853
# 6   (929) 337-6384  1859.244054
# 7                    331.540193
# 8   (929) 969-3073  1022.736125
# 9   (347) 916-1062   149.087879
# 10  (718) 278-2400  1474.349450
# 11  (718) 388-2216   913.119726
# 12  (718) 855-8729   517.844803
# 13  (718) 963-2378   529.963892
# 14  (917) 909-1819  1456.303155
# 15  (347) 422-0194  1609.135717
# 16  (347) 889-7400   535.426503
# 17  (718) 596-6700  3850.308195
# 18  (347) 542-4680  1605.088750
# 19  (718) 455-9664  3001.095678

# %% [markdown]
# ## **Check Results**

# %%
# How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 310

# %% [markdown]
# # **Data Cleaning**

# %%
# Converting the JSON file to a dataframe
df = pd.read_json(JSON_FILE)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             980 non-null    object
#  1   alias          980 non-null    object
#  2   name           980 non-null    object
#  3   image_url      980 non-null    object
#  4   is_closed      980 non-null    bool
#  5   url            980 non-null    object
#  6   review_count   980 non-null    int64
#  7   categories     980 non-null    object
#  8   rating         980 non-null    float64
#  9   coordinates    980 non-null    object
#  10  transactions   980 non-null    object
#  11  price          719 non-null    object
#  12  location       980 non-null    object
#  13  phone          980 non-null    object
#  14  display_phone  980 non-null    object
#  15  distance       980 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 115.9+ KB

# %%
df.drop(['display_phone', 'phone', 'distance', 'price', 'id', 'is_closed'], axis=1, inplace=True)

# %%
# Function to filter out restaurants with 20 or fewer reviews
def filter_restaurants(df):
    filtered_dataframe=df[df['review_count']>=20]
    return filtered_dataframe
# Call Function to eliminate restaurants with less than 20 reviews
df =filter_restaurants(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 848 entries, 0 to 979
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   alias         848 non-null    object
#  1   name          848 non-null    object
#  2   image_url     848 non-null    object
#  3   url           848 non-null    object
#  4   review_count  848 non-null    int64
#  5   categories    848 non-null    object
#  6   rating        848 non-null    float64
#  7   coordinates   848 non-null    object
#  8   transactions  848 non-null    object
#  9   location      848 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 72.9+ KB

# %%
# Saving dataset to as a CSV File:
df.to_csv('ydf', index=False)
