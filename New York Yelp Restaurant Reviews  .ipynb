# %% [markdown]
# # **New York Restaurant Reviews**

# %% [markdown]
# ## **Imports**

# %%
# Imports 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports 
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# # **Load Credentials and Create Yelp API Object**

# %%
# Load API Credentials:
with open("F:\\Desktop Backup\\talen\\.secret\\yelp_api.json",'r') as f:
    login = json.load(f)

# %%
# Show Login Keys:
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'],timeout_s=5.0)

# %%
# set our API call parameters and filename before the first call
location = 'Brooklyn, NY 11211 '
term = 'Pizza'

# %%
location.split(',')[0]
# Out:
# 'Brooklyn'

# %%
## Specify fodler for saving data


FOLDER ='Data/'

os.makedirs(FOLDER,exist_ok=True)

# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %% [markdown]
# ## **Create Json File and Check for It.**

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)

## If it does not exist: 
if file_exists ==False:
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder,exist_ok=True)
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE,'w')as f:
        json.dump([],f)
        
## If it exists, inform user
else:
       print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Brooklyn-Pizza.json already exists.

# %% [markdown]
# # **Make the first API call on New York Restaurants**

# %%
# use our yelp_api variable's search_query method to perform our API call
results = yelp.search_query(term=term,location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 5500

# %%
results['region']
# Out:
# {'center': {'longitude': -73.94966125488281, 'latitude': 40.71264321986641}}

# %%
results['businesses']
# Out:
# [{'id': 'v1DHGRNCH9247WLYoaoA9A',
#   'alias': 'l-industrie-pizzeria-brooklyn',
#   'name': "L'industrie Pizzeria",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1-VBwAOj0g9YKYey3V-Z6Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 1194,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.71162, 'longitude': -73.95783},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '254 S 2nd St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['254 S 2nd St', 'Brooklyn, NY 11211']},
#   'phone': '+17185990002',
#   'display_phone': '(718) 599-0002',
#   'distance': 701.8952662330755},
#  {'id': 'ON7ihGoWgZaBFDaLCYpk2Q',
#   'alias': 'rome-to-brooklyn-pizza-brooklyn-2',
#   'name': 'Rome To Brooklyn Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4JavGLx9XtaLrrNzj36Vjg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rome-to-brooklyn-pizza-brooklyn-2?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 173,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.711886016839244, 'longitude': -73.9429006},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '755 Grand St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['755 Grand St', 'Brooklyn, NY 11211']},
#   'phone': '+17182693239',
#   'display_phone': '(718) 269-3239',
#   'distance': 576.0092018985303},
#  {'id': 'zj8Lq1T8KIC5zwFief15jg',
#   'alias': 'prince-street-pizza-new-york-2',
#   'name': 'Prince Street Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2-U43PXg_c4tTOmeMnfSzg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 5127,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72308755605564,
#    'longitude': -73.99453001177575},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '27 Prince St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['27 Prince St', 'New York, NY 10012']},
#   'phone': '+12129664100',
#   'display_phone': '(212) 966-4100',
#   'distance': 3955.7678469664183},
#  {'id': 'r1PWMTbFXBmEhi0scGPf3w',
#   'alias': 'aces-pizza-brooklyn',
#   'name': "Ace's Pizza",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/id-UXjLag2J47O_JkICU6A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/aces-pizza-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 175,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.71505, 'longitude': -73.958365},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '637 Driggs Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['637 Driggs Ave', 'Brooklyn, NY 11211']},
#   'phone': '+13477254366',
#   'display_phone': '(347) 725-4366',
#   'distance': 782.179585946517},
#  {'id': 'GRXvvB1OKMuW4XDWEaVAlg',
#   'alias': 'joes-pizza-brooklyn-8',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0WEXB_9LUY86MTKnc2UXug/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-brooklyn-8?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 461,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7168952, 'longitude': -73.95892996733771},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '216 Bedford Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['216 Bedford Ave', 'Brooklyn, NY 11249']},
#   'phone': '+17183882216',
#   'display_phone': '(718) 388-2216',
#   'distance': 913.1197256251238},
#  {'id': 'WE_dce2JKcv-VoFNaqiJ4w',
#   'alias': 'carmines-pizzeria-brooklyn',
#   'name': "Carmine's Pizzeria",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/V6LFN2p5zVHu78FvXnVZ7g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/carmines-pizzeria-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 541,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.714987, 'longitude': -73.94414},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '358 Graham Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['358 Graham Ave', 'Brooklyn, NY 11211']},
#   'phone': '+17187829659',
#   'display_phone': '(718) 782-9659',
#   'distance': 530.7604975886186},
#  {'id': 'LO2kgBEQZJ-ceFbj6-UaEA',
#   'alias': 'mos-general-pizza-and-provisions-brooklyn',
#   'name': "Mo's General Pizza & Provisions",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cIYsGoJtwXp-uf5Kn_aG_w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mos-general-pizza-and-provisions-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 40,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.71562045514015, 'longitude': -73.9494481},
#   'transactions': [],
#   'location': {'address1': '620 Lorimer St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['620 Lorimer St', 'Brooklyn, NY 11211']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 331.5401933984459},
#  {'id': 'pGr5QuQU7Ur5GHLvXbT8bw',
#   'alias': 'paulie-gees-brooklyn',
#   'name': "Paulie Gee's",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MyPi1nWBr9Nf9nb4R3wQbg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/paulie-gees-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 1362,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.729546, 'longitude': -73.958568},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '60 Greenpoint Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['60 Greenpoint Ave', 'Brooklyn, NY 11222']},
#   'phone': '+13479873747',
#   'display_phone': '(347) 987-3747',
#   'distance': 2018.1837198784995},
#  {'id': 'lxPVSGnZ7YTiO5OGrqBS8Q',
#   'alias': 'vinnies-pizzeria-brooklyn',
#   'name': "Vinnie's Pizzeria",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-6rgJe3eIc87ZpsiftFESg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/vinnies-pizzeria-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 760,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7189, 'longitude': -73.956843},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '148 Bedford Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['148 Bedford Ave', 'Brooklyn, NY 11211']},
#   'phone': '+17187827078',
#   'display_phone': '(718) 782-7078',
#   'distance': 925.627059811272},
#  {'id': 'RqRCx09k0PZ4sZJgOxbAIA',
#   'alias': 'dough-vale-new-york',
#   'name': 'Dough Vale',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IUKwDlCnFx1-brvwmOjn_Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dough-vale-new-york?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 113,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.70933, 'longitude': -73.95407},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '330 S 3rd St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['330 S 3rd St', 'New York, NY 11211']},
#   'phone': '+13478897400',
#   'display_phone': '(347) 889-7400',
#   'distance': 535.4265025680102},
#  {'id': '1yd-Hq0UFuKN4bY6X2hYVQ',
#   'alias': 'sals-pizzeria-brooklyn',
#   'name': "Sal's Pizzeria",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/d0CEJ8Oioq6wEKtSW6GTog/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sals-pizzeria-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 207,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.71322, 'longitude': -73.94911},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '544 Lorimer St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['544 Lorimer St', 'Brooklyn, NY 11211']},
#   'phone': '+17183886838',
#   'display_phone': '(718) 388-6838',
#   'distance': 79.07588560963505},
#  {'id': 'FhXjAc6nKLf414KxYujUHw',
#   'alias': 'robertas-brooklyn-2',
#   'name': "Roberta's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Cx9X4Q4-Visr4pzqYuNoEQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/robertas-brooklyn-2?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 3323,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.70493, 'longitude': -73.93399},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '261 Moore St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11206',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['261 Moore St', 'Brooklyn, NY 11206']},
#   'phone': '+17184171118',
#   'display_phone': '(718) 417-1118',
#   'distance': 1574.938853168854},
#  {'id': 'KEEXuHCYhsQJ-zpJhu98bA',
#   'alias': 'joes-pizza-new-york-148',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FluVgKezP5ifs7greHV8Qg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-new-york-148?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 2092,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7547, 'longitude': -73.98696},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '1435 Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1435 Broadway', 'New York, NY 10018']},
#   'phone': '+16465594878',
#   'display_phone': '(646) 559-4878',
#   'distance': 5635.742404027695},
#  {'id': 'CFR-HzVHKWRMpMAR3LAhzg',
#   'alias': 'montesacro-pinseria-brooklyn-brooklyn',
#   'name': 'Montesacro Pinseria Brooklyn',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5xTDQsC37mQ55E08iVxBxQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/montesacro-pinseria-brooklyn-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 270,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.71338, 'longitude': -73.95136},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '432 Union Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['432 Union Ave', 'Brooklyn, NY 11211']},
#   'phone': '+13479161062',
#   'display_phone': '(347) 916-1062',
#   'distance': 149.08787907869174},
#  {'id': '2FgUndzCT_jJATbmrBDVBg',
#   'alias': 'paulie-gees-slice-shop-brooklyn',
#   'name': "Paulie Gee's Slice Shop",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/x01yyTgGYaW9b_YODsZgCQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/paulie-gees-slice-shop-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 367,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72836, 'longitude': -73.9572},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '110 Franklin St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['110 Franklin St', 'Brooklyn, NY 11222']},
#   'phone': '+19293376384',
#   'display_phone': '(929) 337-6384',
#   'distance': 1859.2440542825516},
#  {'id': 'ysqgdbSrezXgVwER2kQWKA',
#   'alias': 'julianas-brooklyn-3',
#   'name': "Juliana's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/od36nFW220aMFAnNP00ocw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/julianas-brooklyn-3?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 2724,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.70274718768062,
#    'longitude': -73.99343490196397},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '19 Old Fulton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#   'phone': '+17185966700',
#   'display_phone': '(718) 596-6700',
#   'distance': 3850.308194886269},
#  {'id': 'EsHcyOLHaK76bQuU7bwiTw',
#   'alias': 'tonys-pizzeria-and-restaurant-brooklyn-3',
#   'name': "Tony's Pizzeria & Restaurant",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/viqI7JzZtEW4qFW_JmpF0w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tonys-pizzeria-and-restaurant-brooklyn-3?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 368,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.699286, 'longitude': -73.918724},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '443 Knickerbocker Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['443 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#   'phone': '+17184559664',
#   'display_phone': '(718) 455-9664',
#   'distance': 3001.095678100864},
#  {'id': 'ozYKGhJoGkQbFGskBeONuw',
#   'alias': 'the-original-square-of-soho-brooklyn',
#   'name': 'The Original Square Of Soho',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SlMVxJ6UCNf6ahRJHDz_NQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-original-square-of-soho-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 18,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.70740304957788,
#    'longitude': -73.93186589137349},
#   'transactions': ['delivery'],
#   'location': {'address1': '2 Knickerbocker Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 1609.135716699237},
#  {'id': 'aPn2_EtjfHduXEmEBNxuFA',
#   'alias': 'rosas-pizza-brooklyn',
#   'name': "Rosa's Pizza",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TtcGEKqRXYjkxNalZYapTA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rosas-pizza-brooklyn?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 199,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7139499, 'longitude': -73.95563},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '374 Metropolitan Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['374 Metropolitan Ave', 'Brooklyn, NY 11211']},
#   'phone': '+17189632378',
#   'display_phone': '(718) 963-2378',
#   'distance': 529.6300466056173},
#  {'id': 'Q9F2ocrmYuGt1yn3M7MOBw',
#   'alias': 'lucali-brooklyn-3',
#   'name': 'Lucali',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rMlNCZkNG2Nizhp8aBYKng/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lucali-brooklyn-3?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 2018,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.681840746711224, 'longitude': -74.0003327},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '575 Henry St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11231',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['575 Henry St', 'Brooklyn, NY 11231']},
#   'phone': '+17188584086',
#   'display_phone': '(718) 858-4086',
#   'distance': 5475.3536096983435}]

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                      alias  \
# 0   v1DHGRNCH9247WLYoaoA9A              l-industrie-pizzeria-brooklyn
# 1   ON7ihGoWgZaBFDaLCYpk2Q          rome-to-brooklyn-pizza-brooklyn-2
# 2   zj8Lq1T8KIC5zwFief15jg             prince-street-pizza-new-york-2
# 3   r1PWMTbFXBmEhi0scGPf3w                        aces-pizza-brooklyn
# 4   GRXvvB1OKMuW4XDWEaVAlg                      joes-pizza-brooklyn-8
# 5   WE_dce2JKcv-VoFNaqiJ4w                 carmines-pizzeria-brooklyn
# 6   LO2kgBEQZJ-ceFbj6-UaEA  mos-general-pizza-and-provisions-brooklyn
# 7   pGr5QuQU7Ur5GHLvXbT8bw                       paulie-gees-brooklyn
# 8   lxPVSGnZ7YTiO5OGrqBS8Q                  vinnies-pizzeria-brooklyn
# 9   RqRCx09k0PZ4sZJgOxbAIA                        dough-vale-new-york
# 10  1yd-Hq0UFuKN4bY6X2hYVQ                     sals-pizzeria-brooklyn
# 11  FhXjAc6nKLf414KxYujUHw                        robertas-brooklyn-2
# 12  KEEXuHCYhsQJ-zpJhu98bA                    joes-pizza-new-york-148
# 13  CFR-HzVHKWRMpMAR3LAhzg      montesacro-pinseria-brooklyn-brooklyn
# 14  2FgUndzCT_jJATbmrBDVBg            paulie-gees-slice-shop-brooklyn
# 15  ysqgdbSrezXgVwER2kQWKA                        julianas-brooklyn-3
# 16  EsHcyOLHaK76bQuU7bwiTw   tonys-pizzeria-and-restaurant-brooklyn-3
# 17  ozYKGhJoGkQbFGskBeONuw       the-original-square-of-soho-brooklyn
# 18  aPn2_EtjfHduXEmEBNxuFA                       rosas-pizza-brooklyn
# 19  Q9F2ocrmYuGt1yn3M7MOBw                          lucali-brooklyn-3
#
#                                name  \
# 0              L'industrie Pizzeria
# 1            Rome To Brooklyn Pizza
# 2               Prince Street Pizza
# 3                       Ace's Pizza
# 4                       Joe's Pizza
# 5                Carmine's Pizzeria
# 6   Mo's General Pizza & Provisions
# 7                      Paulie Gee's
# 8                 Vinnie's Pizzeria
# 9                        Dough Vale
# 10                   Sal's Pizzeria
# 11                        Roberta's
# 12                      Joe's Pizza
# 13     Montesacro Pinseria Brooklyn
# 14          Paulie Gee's Slice Shop
# 15                        Juliana's
# 16     Tony's Pizzeria & Restaurant
# 17      The Original Square Of Soho
# 18                     Rosa's Pizza
# 19                           Lucali
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/1-VBwA...      False
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/4JavGL...      False
# 2   https://s3-media1.fl.yelpcdn.com/bphoto/2-U43P...      False
# 3   https://s3-media2.fl.yelpcdn.com/bphoto/id-UXj...      False
# 4   https://s3-media3.fl.yelpcdn.com/bphoto/0WEXB_...      False
# 5   https://s3-media4.fl.yelpcdn.com/bphoto/V6LFN2...      False
# 6   https://s3-media4.fl.yelpcdn.com/bphoto/cIYsGo...      False
# 7   https://s3-media1.fl.yelpcdn.com/bphoto/MyPi1n...      False
# 8   https://s3-media1.fl.yelpcdn.com/bphoto/-6rgJe...      False
# 9   https://s3-media3.fl.yelpcdn.com/bphoto/IUKwDl...      False
# 10  https://s3-media2.fl.yelpcdn.com/bphoto/d0CEJ8...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/Cx9X4Q...      False
# 12  https://s3-media4.fl.yelpcdn.com/bphoto/FluVgK...      False
# 13  https://s3-media2.fl.yelpcdn.com/bphoto/5xTDQs...      False
# 14  https://s3-media4.fl.yelpcdn.com/bphoto/x01yyT...      False
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/od36nF...      False
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/viqI7J...      False
# 17  https://s3-media4.fl.yelpcdn.com/bphoto/SlMVxJ...      False
# 18  https://s3-media4.fl.yelpcdn.com/bphoto/TtcGEK...      False
# 19  https://s3-media1.fl.yelpcdn.com/bphoto/rMlNCZ...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/l-industrie-pizzeria-...          1194
# 1   https://www.yelp.com/biz/rome-to-brooklyn-pizz...           173
# 2   https://www.yelp.com/biz/prince-street-pizza-n...          5127
# 3   https://www.yelp.com/biz/aces-pizza-brooklyn?a...           175
# 4   https://www.yelp.com/biz/joes-pizza-brooklyn-8...           461
# 5   https://www.yelp.com/biz/carmines-pizzeria-bro...           541
# 6   https://www.yelp.com/biz/mos-general-pizza-and...            40
# 7   https://www.yelp.com/biz/paulie-gees-brooklyn?...          1362
# 8   https://www.yelp.com/biz/vinnies-pizzeria-broo...           760
# 9   https://www.yelp.com/biz/dough-vale-new-york?a...           113
# 10  https://www.yelp.com/biz/sals-pizzeria-brookly...           207
# 11  https://www.yelp.com/biz/robertas-brooklyn-2?a...          3323
# 12  https://www.yelp.com/biz/joes-pizza-new-york-1...          2092
# 13  https://www.yelp.com/biz/montesacro-pinseria-b...           270
# 14  https://www.yelp.com/biz/paulie-gees-slice-sho...           367
# 15  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2724
# 16  https://www.yelp.com/biz/tonys-pizzeria-and-re...           368
# 17  https://www.yelp.com/biz/the-original-square-o...            18
# 18  https://www.yelp.com/biz/rosas-pizza-brooklyn?...           199
# 19  https://www.yelp.com/biz/lucali-brooklyn-3?adj...          2018
#
#                                            categories  rating  \
# 0              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 1   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 2   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 3   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 4              [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 5   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 6              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 7              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 8   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 9   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 10  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 11  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 12             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 13  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 14  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 15             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 16  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 17             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 18  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 19             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
#
#                                           coordinates        transactions  \
# 0      {'latitude': 40.71162, 'longitude': -73.95783}  [pickup, delivery]
# 1   {'latitude': 40.711886016839244, 'longitude': ...  [pickup, delivery]
# 2   {'latitude': 40.72308755605564, 'longitude': -...  [pickup, delivery]
# 3     {'latitude': 40.71505, 'longitude': -73.958365}          [delivery]
# 4   {'latitude': 40.7168952, 'longitude': -73.9589...  [pickup, delivery]
# 5     {'latitude': 40.714987, 'longitude': -73.94414}  [pickup, delivery]
# 6   {'latitude': 40.71562045514015, 'longitude': -...                  []
# 7    {'latitude': 40.729546, 'longitude': -73.958568}          [delivery]
# 8      {'latitude': 40.7189, 'longitude': -73.956843}  [delivery, pickup]
# 9      {'latitude': 40.70933, 'longitude': -73.95407}  [pickup, delivery]
# 10     {'latitude': 40.71322, 'longitude': -73.94911}  [pickup, delivery]
# 11     {'latitude': 40.70493, 'longitude': -73.93399}  [pickup, delivery]
# 12      {'latitude': 40.7547, 'longitude': -73.98696}  [pickup, delivery]
# 13     {'latitude': 40.71338, 'longitude': -73.95136}  [pickup, delivery]
# 14      {'latitude': 40.72836, 'longitude': -73.9572}          [delivery]
# 15  {'latitude': 40.70274718768062, 'longitude': -...          [delivery]
# 16   {'latitude': 40.699286, 'longitude': -73.918724}  [pickup, delivery]
# 17  {'latitude': 40.70740304957788, 'longitude': -...          [delivery]
# 18   {'latitude': 40.7139499, 'longitude': -73.95563}  [pickup, delivery]
# 19  {'latitude': 40.681840746711224, 'longitude': ...          [delivery]
#
#    price                                           location         phone  \
# 0      $  {'address1': '254 S 2nd St', 'address2': '', '...  +17185990002
# 1    NaN  {'address1': '755 Grand St', 'address2': None,...  +17182693239
# 2      $  {'address1': '27 Prince St', 'address2': None,...  +12129664100
# 3     $$  {'address1': '637 Driggs Ave', 'address2': '',...  +13477254366
# 4      $  {'address1': '216 Bedford Ave', 'address2': ''...  +17183882216
# 5     $$  {'address1': '358 Graham Ave', 'address2': '',...  +17187829659
# 6    NaN  {'address1': '620 Lorimer St', 'address2': '',...
# 7     $$  {'address1': '60 Greenpoint Ave', 'address2': ...  +13479873747
# 8      $  {'address1': '148 Bedford Ave', 'address2': ''...  +17187827078
# 9     $$  {'address1': '330 S 3rd St', 'address2': None,...  +13478897400
# 10     $  {'address1': '544 Lorimer St', 'address2': '',...  +17183886838
# 11    $$  {'address1': '261 Moore St', 'address2': '', '...  +17184171118
# 12     $  {'address1': '1435 Broadway', 'address2': '', ...  +16465594878
# 13    $$  {'address1': '432 Union Ave', 'address2': None...  +13479161062
# 14     $  {'address1': '110 Franklin St', 'address2': ''...  +19293376384
# 15    $$  {'address1': '19 Old Fulton St', 'address2': '...  +17185966700
# 16     $  {'address1': '443 Knickerbocker Ave', 'address...  +17184559664
# 17   NaN  {'address1': '2 Knickerbocker Ave', 'address2'...
# 18     $  {'address1': '374 Metropolitan Ave', 'address2...  +17189632378
# 19    $$  {'address1': '575 Henry St', 'address2': None,...  +17188584086
#
#      display_phone     distance
# 0   (718) 599-0002   701.895266
# 1   (718) 269-3239   576.009202
# 2   (212) 966-4100  3955.767847
# 3   (347) 725-4366   782.179586
# 4   (718) 388-2216   913.119726
# 5   (718) 782-9659   530.760498
# 6                    331.540193
# 7   (347) 987-3747  2018.183720
# 8   (718) 782-7078   925.627060
# 9   (347) 889-7400   535.426503
# 10  (718) 388-6838    79.075886
# 11  (718) 417-1118  1574.938853
# 12  (646) 559-4878  5635.742404
# 13  (347) 916-1062   149.087879
# 14  (929) 337-6384  1859.244054
# 15  (718) 596-6700  3850.308195
# 16  (718) 455-9664  3001.095678
# 17                  1609.135717
# 18  (718) 963-2378   529.630047
# 19  (718) 858-4086  5475.353610

# %% [markdown]
# ## **Check Results**

# %%
# How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 275

# %% [markdown]
# # **Data Cleaning**

# %%
# Converting the JSON file to a dataframe
df = pd.read_json(JSON_FILE)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             980 non-null    object
#  1   alias          980 non-null    object
#  2   name           980 non-null    object
#  3   image_url      980 non-null    object
#  4   is_closed      980 non-null    bool
#  5   url            980 non-null    object
#  6   review_count   980 non-null    int64
#  7   categories     980 non-null    object
#  8   rating         980 non-null    float64
#  9   coordinates    980 non-null    object
#  10  transactions   980 non-null    object
#  11  price          719 non-null    object
#  12  location       980 non-null    object
#  13  phone          980 non-null    object
#  14  display_phone  980 non-null    object
#  15  distance       980 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 115.9+ KB

# %%
df.drop(['display_phone', 'phone', 'distance', 'price', 'id', 'is_closed'], axis=1, inplace=True)

# %%
# Function to filter out restaurants with 20 or fewer reviews
def filter_restaurants(df):
    filtered_dataframe=df[df['review_count']>=20]
    return filtered_dataframe
# Call Function to eliminate restaurants with less than 20 reviews
df =filter_restaurants(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 848 entries, 0 to 979
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   alias         848 non-null    object
#  1   name          848 non-null    object
#  2   image_url     848 non-null    object
#  3   url           848 non-null    object
#  4   review_count  848 non-null    int64
#  5   categories    848 non-null    object
#  6   rating        848 non-null    float64
#  7   coordinates   848 non-null    object
#  8   transactions  848 non-null    object
#  9   location      848 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 72.9+ KB

# %%
# Saving dataset to as a CSV File:
df.to_csv('ydf', index=False)
