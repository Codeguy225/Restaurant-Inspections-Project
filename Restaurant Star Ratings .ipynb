# %% [markdown]
# # **Restaurant Star Ratings**

# %% [markdown]
# ## **Imports**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly
# %matplotlib inline
from wordcloud import WordCloud
import re
import nltk
from nltk.corpus import stopwords

#Sklearn preprocessing
from sklearn import preprocessing,set_config
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder,StandardScaler,LabelEncoder
#Scipy
from scipy import stats
from scipy.stats import norm

#Sklearn Models
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn import preprocessing, set_config
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer,make_column_selector,make_column_transformer
from sklearn.linear_model import LogisticRegression
import warnings
from sklearn.decomposition import PCA

# Geospatial map
import folium
import pandas as pd
import geopandas as gpd
from folium.plugins import MarkerCluster

# Warnings 
import warnings 
warnings.filterwarnings("ignore")

# Configuring diagrams
set_config(display = 'diagram')

# %% [markdown]
# ## **Import Data**

# %%
SR1 = pd.read_csv('F:\Coding Dojo\Data\Resturant Start Ratings\one-star-michelin-restaurants.csv')

# %%
SR2 = pd.read_csv('F:/Coding Dojo/Data/Resturant Start Ratings/two-stars-michelin-restaurants.csv')

# %%
SR3 = pd.read_csv('F:/Coding Dojo/Data/Resturant Start Ratings/three-stars-michelin-restaurants.csv')

# %%
SR1.head()
# Out:
#             name  year   latitude  longitude            city   region zipCode  \
# 0   Kilian Stuba  2019  47.348580   10.17114  Kleinwalsertal  Austria   87568
# 1  Pfefferschiff  2019  47.837870   13.07917        Hallwang  Austria    5300
# 2      Esszimmer  2019  47.806850   13.03409        Salzburg  Austria    5020
# 3     Carpe Diem  2019  47.800010   13.04006        Salzburg  Austria    5020
# 4         Edvard  2019  48.216503   16.36852            Wien  Austria    1010
#
#            cuisine  price                                                url
# 0         Creative  $$$$$  https://guide.michelin.com/at/en/vorarlberg/kl...
# 1  Classic cuisine  $$$$$  https://guide.michelin.com/at/en/salzburg-regi...
# 2         Creative  $$$$$  https://guide.michelin.com/at/en/salzburg-regi...
# 3   Market cuisine  $$$$$  https://guide.michelin.com/at/en/salzburg-regi...
# 4   Modern cuisine   $$$$  https://guide.michelin.com/at/en/vienna/wien/r...

# %%
SR2.head()
# Out:
#                                name  year  latitude  longitude      city  \
# 0                  SENNS.Restaurant  2019  47.83636   13.06389  Salzburg
# 1                            Ikarus  2019  47.79536   13.00695  Salzburg
# 2                       Mraz & Sohn  2019  48.23129   16.37637      Wien
# 3               Konstantin Filippou  2019  48.21056   16.37996      Wien
# 4  Silvio Nickol Gourmet Restaurant  2019  48.20558   16.37693      Wien
#
#     region zipCode         cuisine  price  \
# 0  Austria    5020        Creative  $$$$$
# 1  Austria    5020        Creative  $$$$$
# 2  Austria    1200        Creative  $$$$$
# 3  Austria    1010  Modern cuisine  $$$$$
# 4  Austria    1010  Modern cuisine  $$$$$
#
#                                                  url
# 0  https://guide.michelin.com/at/en/salzburg-regi...
# 1  https://guide.michelin.com/at/en/salzburg-regi...
# 2  https://guide.michelin.com/at/en/vienna/wien/r...
# 3  https://guide.michelin.com/at/en/vienna/wien/r...
# 4  https://guide.michelin.com/at/en/vienna/wien/r...

# %%
SR3.head()
# Out:
#             name  year  latitude  longitude                 city      region  \
# 0         Amador  2019  48.25406   16.35915                 Wien     Austria
# 1        Manresa  2019  37.22761 -121.98071  South San Francisco  California
# 2           Benu  2019  37.78521 -122.39876        San Francisco  California
# 3         Quince  2019  37.79762 -122.40337        San Francisco  California
# 4  Atelier Crenn  2019  37.79835 -122.43586        San Francisco  California
#
#   zipCode       cuisine  price  \
# 0    1190      Creative  $$$$$
# 1   95030  Contemporary   $$$$
# 2   94105         Asian   $$$$
# 3   94133  Contemporary   $$$$
# 4   94123  Contemporary   $$$$
#
#                                                  url
# 0  https://guide.michelin.com/at/en/vienna/wien/r...
# 1  https://guide.michelin.com/us/en/california/so...
# 2  https://guide.michelin.com/us/en/california/sa...
# 3  https://guide.michelin.com/us/en/california/sa...
# 4  https://guide.michelin.com/us/en/california/sa...

# %%
# add a 'Star Rating' Column to each Dataframe 
SR1['Star Rating'] = 1
SR2['Star Rating'] = 2
SR3['Star Rating'] = 3

# %%
# Combine all dataframes 
sr = pd.concat([SR1, SR2, SR3], ignore_index = True)

# %%
sr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 695 entries, 0 to 694
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         695 non-null    object
#  1   year         695 non-null    int64
#  2   latitude     695 non-null    float64
#  3   longitude    695 non-null    float64
#  4   city         693 non-null    object
#  5   region       695 non-null    object
#  6   zipCode      501 non-null    object
#  7   cuisine      695 non-null    object
#  8   price        519 non-null    object
#  9   url          695 non-null    object
#  10  Star Rating  695 non-null    int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 59.9+ KB

# %%
sr.describe()
# Out:
#               year    latitude   longitude  Star Rating
# count   695.000000  695.000000  695.000000   695.000000
# mean   2018.943885   37.260124    4.417000     1.261871
# std       0.230310   18.025875   81.095189     0.545270
# min    2018.000000  -23.634005 -123.719444     1.000000
# 25%    2019.000000   25.040718  -73.982920     1.000000
# 50%    2019.000000   40.727130   -0.149570     1.000000
# 75%    2019.000000   51.508962  100.578855     1.000000
# max    2019.000000   63.436260  127.102570     3.000000

# %%
sr.head()
# Out:
#             name  year   latitude  longitude            city   region zipCode  \
# 0   Kilian Stuba  2019  47.348580   10.17114  Kleinwalsertal  Austria   87568
# 1  Pfefferschiff  2019  47.837870   13.07917        Hallwang  Austria    5300
# 2      Esszimmer  2019  47.806850   13.03409        Salzburg  Austria    5020
# 3     Carpe Diem  2019  47.800010   13.04006        Salzburg  Austria    5020
# 4         Edvard  2019  48.216503   16.36852            Wien  Austria    1010
#
#            cuisine  price                                                url  \
# 0         Creative  $$$$$  https://guide.michelin.com/at/en/vorarlberg/kl...
# 1  Classic cuisine  $$$$$  https://guide.michelin.com/at/en/salzburg-regi...
# 2         Creative  $$$$$  https://guide.michelin.com/at/en/salzburg-regi...
# 3   Market cuisine  $$$$$  https://guide.michelin.com/at/en/salzburg-regi...
# 4   Modern cuisine   $$$$  https://guide.michelin.com/at/en/vienna/wien/r...
#
#    Star Rating
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
sr.isna().sum()
# Out:
# name             0
# year             0
# latitude         0
# longitude        0
# city             2
# region           0
# zipCode        194
# cuisine          0
# price          176
# url              0
# Star Rating      0
# dtype: int64

# %%
def drop_columns(sr):
    # Check if 'zipcode' and 'price' columns exist in the dataframe
    if 'zipcode' in sr.columns and 'price' in sr.columns:
        # Drop the specified columns
        dcsr = sr.drop(['zipcode', 'price'], axis=1)
        print("Columns 'zipcode' and 'price' dropped successfully.")
    else:
        print("Columns 'zipcode' and 'price' not found.")
# Example usage:
# Assuming 'your_dataframe' is the name of your DataFrame
drop_columns(sr)
# Out:
# Columns 'zipcode' and 'price' not found.

# %%
# Filter for Michelin star restaurants in New York
msny = sr[(sr['city'] == 'New York')]

# %%
print (msny)
# Out:
#                               name  year   latitude  longitude      city  \
# 204                      Del Posto  2019  40.743270  -74.00770  New York
# 205      Le Grill de Joël Robuchon  2019  40.742897  -74.00770  New York
# 206                       L'Appart  2019  40.711903  -74.01544  New York
# 207                          Okuda  2019  40.743793  -74.00633  New York
# 208                         Wallsé  2019  40.735380  -74.00814  New York
# ..                             ...   ...        ...        ...       ...
# 680                           Masa  2019  40.768550  -73.98335  New York
# 681                         Per Se  2019  40.768280  -73.98292  New York
# 682                   Le Bernardin  2019  40.761770  -73.98223  New York
# 683            Eleven Madison Park  2019  40.741700  -73.98712  New York
# 684  Chef's Table at Brooklyn Fare  2019  40.688720  -73.98581  New York
#
#             region zipCode       cuisine price  \
# 204  New York City   10011       Italian  $$$$
# 205  New York City     NaN        French  $$$$
# 206  New York City   10281        French  $$$$
# 207  New York City     NaN      Japanese  $$$$
# 208  New York City   10014      Austrian  $$$$
# ..             ...     ...           ...   ...
# 680  New York City   10019      Japanese  $$$$
# 681  New York City   10019  Contemporary  $$$$
# 682  New York City   10019       Seafood  $$$$
# 683  New York City   10010  Contemporary  $$$$
# 684  New York City   10018  Contemporary  $$$$
#
#                                                    url  Star Rating
# 204  https://guide.michelin.com/us/en/new-york-stat...            1
# 205  https://guide.michelin.com/us/en/new-york-stat...            1
# 206  https://guide.michelin.com/us/en/new-york-stat...            1
# 207  https://guide.michelin.com/us/en/new-york-stat...            1
# 208  https://guide.michelin.com/us/en/new-york-stat...            1
# ..                                                 ...          ...
# 680  https://guide.michelin.com/us/en/new-york-stat...            3
# 681  https://guide.michelin.com/us/en/new-york-stat...            3
# 682  https://guide.michelin.com/us/en/new-york-stat...            3
# 683  https://guide.michelin.com/us/en/new-york-stat...            3
# 684  https://guide.michelin.com/us/en/new-york-stat...            3
#
# [74 rows x 11 columns]

# %%
msny.head()
# Out:
#                           name  year   latitude  longitude      city  \
# 204                  Del Posto  2019  40.743270  -74.00770  New York
# 205  Le Grill de Joël Robuchon  2019  40.742897  -74.00770  New York
# 206                   L'Appart  2019  40.711903  -74.01544  New York
# 207                      Okuda  2019  40.743793  -74.00633  New York
# 208                     Wallsé  2019  40.735380  -74.00814  New York
#
#             region zipCode   cuisine price  \
# 204  New York City   10011   Italian  $$$$
# 205  New York City     NaN    French  $$$$
# 206  New York City   10281    French  $$$$
# 207  New York City     NaN  Japanese  $$$$
# 208  New York City   10014  Austrian  $$$$
#
#                                                    url  Star Rating
# 204  https://guide.michelin.com/us/en/new-york-stat...            1
# 205  https://guide.michelin.com/us/en/new-york-stat...            1
# 206  https://guide.michelin.com/us/en/new-york-stat...            1
# 207  https://guide.michelin.com/us/en/new-york-stat...            1
# 208  https://guide.michelin.com/us/en/new-york-stat...            1

# %%
nyc_rsr = msny

# %%
# Save the filtered dataset to a new CSV file
nyc_rsr.to_csv('nyc_rsr', index=False)

# %%
# Function to retrive list of Restaurant names from Michelin Star dataset to filter out of Inspections data
def compile_unique_restaurant_names(nyc_rsr, name):
    """
    Compiles a list of unique restaurant names from a given dataset.
Args:
    - dataset_filename (str): The filename of the dataset containing restaurant names.
    - restaurant_name_column (str): The name of the column in the dataset that contains restaurant names.

    Returns:
    - List of unique restaurant names.
    """
    # Get a list of unique restaurant names
    unique_names = nyc_rsr[name].unique()

    return unique_names

# %%
#Names list
names_list = compile_unique_restaurant_names(nyc_rsr, 'name')

# %%
sorted_names = sorted(names_list)
for name in sorted_names:
    print(name)
# Out:
# Agern
# Ai Fiori
# Aldea
# Aquavit
# Aska
# Atera
# Atomix
# Babbo
# Bar Uchū
# Blanca
# Blue Hill
# Bouley at Home
# Bâtard
# Café Boulud
# Café China
# Carbone
# Casa Enríque
# Casa Mono
# Caviar Russe
# Chef's Table at Brooklyn Fare
# Claro
# Contra
# Cote
# Daniel
# Del Posto
# Eleven Madison Park
# Faro
# Gabriel Kreuther
# Gotham Bar and Grill
# Gramercy Tavern
# Hirohisa
# Ichimura at Uchū
# Jean-Georges
# Jeju Noodle Bar
# Jewel Bako
# Jungsik
# Junoon
# Kajitsu
# Kanoyama
# Ko
# Kosaka
# Kyo Ya
# L'Appart
# L'Atelier de Joël Robuchon
# Le Bernardin
# Le Coucou
# Le Grill de Joël Robuchon
# Marea
# Masa
# Meadowsweet
# Nix
# NoMad
# Noda
# Okuda
# Oxomoco
# Per Se
# Peter Luger
# Satsuki
# Sushi Amane
# Sushi Ginza Onodera
# Sushi Inoue
# Sushi Nakazawa
# Sushi Noz
# Sushi Yasuda
# Tempura Matsui
# The Clocktower
# The Finch
# The Modern
# The Musket Room
# The River Café
# Tuome
# Uncle Boons
# Wallsé
# ZZ's Clam Bar

# %%
# Loading NYC Restaurant Data
rd =pd.read_csv('rd')

# %%
rd.head()
# Out:
#       CAMIS                          DBA       BORO BUILDING  \
# 0  41408361  BEKY BAKERY AND COFFEE SHOP     Queens     3778
# 1  50124500                 EAT OFF BEAT  Manhattan       75
# 2  50142175                UVA NEXT DOOR  Manhattan     1484
# 3  50107467              CHANCHITOS CAFE   Brooklyn      176
# 4  50104755     FLIK INTERNATIONAL CORP.  Manhattan      599
#
#              STREET  ZIPCODE CUISINE DESCRIPTION INSPECTION DATE  \
# 0        103 STREET  11368.0             Spanish      01/06/2020
# 1          9 AVENUE  10011.0               Other      09/21/2023
# 2          2 AVENUE  10075.0                 NaN      01/01/1900
# 3   ROCKAWAY AVENUE  11233.0                 NaN      01/01/1900
# 4  LEXINGTON AVENUE  10022.0                 NaN      01/01/1900
#
#                                               ACTION VIOLATION CODE  \
# 0  No violations were recorded at the time of thi...            NaN
# 1                  Establishment re-opened by DOHMH.            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
#
#   VIOLATION DESCRIPTION   CRITICAL FLAG  SCORE GRADE  GRADE DATE  \
# 0                   NaN  Not Applicable    NaN   NaN         NaN
# 1                   NaN  Not Applicable    0.0     Z  09/21/2023
# 2                   NaN  Not Applicable    NaN   NaN         NaN
# 3                   NaN  Not Applicable    NaN   NaN         NaN
# 4                   NaN  Not Applicable    NaN   NaN         NaN
#
#                                      INSPECTION TYPE   Latitude  Longitude  \
# 0  Administrative Miscellaneous / Initial Inspection  40.752738 -73.864188
# 1    Pre-permit (Operational) / Reopening Inspection  40.741869 -74.004713
# 2                                                NaN  40.772284 -73.955805
# 3                                                NaN  40.677091 -73.910865
# 4                                                NaN  40.758268 -73.971054
#
#    Council District      Cleaned Restaurant Name
# 0              21.0  BEKY BAKERY AND COFFEE SHOP
# 1               3.0                 EAT OFF BEAT
# 2               5.0                UVA NEXT DOOR
# 3              41.0              CHANCHITOS CAFE
# 4               4.0     FLIK INTERNATIONAL CORP.

# %%
rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208029 entries, 0 to 208028
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   CAMIS                    208029 non-null  int64
#  1   DBA                      207562 non-null  object
#  2   BORO                     208029 non-null  object
#  3   BUILDING                 207653 non-null  object
#  4   STREET                   208023 non-null  object
#  5   ZIPCODE                  205315 non-null  float64
#  6   CUISINE DESCRIPTION      205791 non-null  object
#  7   INSPECTION DATE          208029 non-null  object
#  8   ACTION                   205791 non-null  object
#  9   VIOLATION CODE           204640 non-null  object
#  10  VIOLATION DESCRIPTION    204640 non-null  object
#  11  CRITICAL FLAG            208029 non-null  object
#  12  SCORE                    198416 non-null  float64
#  13  GRADE                    102267 non-null  object
#  14  GRADE DATE               93483 non-null   object
#  15  INSPECTION TYPE          205791 non-null  object
#  16  Latitude                 207772 non-null  float64
#  17  Longitude                207772 non-null  float64
#  18  Council District         204708 non-null  float64
#  19  Cleaned Restaurant Name  207562 non-null  object
# dtypes: float64(5), int64(1), object(14)
# memory usage: 31.7+ MB

# %%
# Create a base map
m = folium.Map(location=[sr['latitude'].mean(), sr['longitude'].mean()], zoom_start=12)

# Add markers for each restaurant
for index, row in sr.iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup=row['name']).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b5c9b09cdd98b9f336a0967d4f6fd89 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b5c9b09cdd98b9f336a0967d4f6fd89&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b5c9b09cdd98b9f336a0967d4f6fd89 = L.map(
#                 &quot;map_0b5c9b09cdd98b9f336a0967d4f6fd89&quot;,
#                 {
#                     center: [37.260123662014394, 4.416999906187051],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c3c5fa6bbaef136cd82cfae04f1ade0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0b5c9b09cdd98b9f336a0967d4f6fd89);
#
#
#             var marker_a450afc45909004f349dd93c42839028 = L.marker(
#                 [47.34858, 10.17114],
#                 {}
#             ).addTo(map_0b5c9b09cdd98b9f336a0967d4f6fd89);
#
#
#         var popup_25d281235eb053f8697b658a35bde01d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b4b10ffbb22796b8f29f4d9b7813cec1 = $(`&lt;div id=&quot;html_b4b10ffbb22796b8f29f4d9b7813cec1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kilian Stuba&lt;/div&gt;`)[0];
#                 popup_25d281235eb053f8697b658a35bde01d.setContent(html_b4b10ffbb22796b8f29f4d9b7813cec1);
#
#
#
#         marker_a450afc45909004f349dd93c42839028.bindPopup(popup_25d281235eb053f8697b658a35bde01d)
#         ;
#
#
#
#
#             var marker_84f702e32c2ca420ee5d2d411148ddb0 = L.marker(
#                 [47.83787, 13.07917],
#                 {}
#             ).addTo(map_0b5c9b09cdd98b9f336a0967d4f6fd89);
#
#
#         var popup_f6bb41f4c870c7eb0136b5a36d3f0f42 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dfd6ba1f095be1be793da67a6cca9c96 = $(`&lt;div id=&quot;html_dfd6ba1f095be1be793da67a6cca9c96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pfefferschiff&lt;/div&gt;`)[0];
#                 popup_f6bb41f4c870c7eb0136b5a36d3f0f42.setContent(html_dfd6ba1f095be1be793da67a6cca9c96);
#
#
#
#         marker_84f702e32c2ca420ee5d2d411148ddb0.bindPopup(popup_f6bb41f4c870c7eb0136b5a36d3f0f42)
#         ;
#
#
#
#
#             var marker_d731ee233a06f85b5817e86e7d4dbcce = L.marker(
#                 [47.80685, 13.03409],
#                 {}
#             ).addTo(map_0b5c9b09cdd98b9f336a0967d4f6fd89);
#
#
#         var popup_4fc328b25a4139e23ed63ccdc61935a0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d04e1d06dad88de9ef783faae6852d84 = $(`&lt;div id=&quot;html_d04e1d06dad88de9ef783faae6852d84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Esszimmer&lt;/div&gt;`)[0];
#                 popup_4fc328b25a4139e23ed63ccdc61935a0.setContent(html_d04e1d06dad88de9ef783faae6852d84);
#
#
#
#         marker_d731ee233a06f85b5817e86e7d4dbcce.bindPopup(popup_4fc328b25a4139e23ed63ccdc61935a0)
#         ;
#
#
#
#
#             var marker_5ebec6127363bee015d5880e3ac7648e = L.marker(
#                 [47.80001, 13.04006],
#                 {}
#             ).addTo(map_0b5c9b09cdd98b9f336a0967d4f6fd89);
#
#
#         var popup_fedb5ee7afca390298c612e524ced670 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f8741431c87cd75d575ef28352bab496 = $(`&lt;div id=&quot;html_f8741431c87cd75d575ef28352bab496&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Carpe Diem&lt;/div&gt;`)[0];
#                 popup_fedb5ee7afca390298c612e524ced670.setContent(html_f8741431c87cd75d575ef28352bab496);
#
#
#
#         marker_5ebec6127363bee015d5880e3ac7648e.bindPopup(popup_fedb5ee7afca390298c612e524ced670)
#         ;
#
#
#
#
#             var marker_c4b385237b610daa162baa3c91be6709 = L.marker(
#                 [48.216503, 16.36852],
#                 {}
#             ).addTo(map_0b5c9b09cdd98b9f336a0967d4f6fd89);
#
#
#         var popup_fba587b1fed8f876008278f47b6a5674 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6d248a46cff1883c3fffce8dbd69985c = $(`&lt;div id=&quot;html_6d248a46cff1883c3fffce8dbd69985c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Edvard&lt;/div&gt;`)[0];
#                 popup_fba587b1fed8f876008278f47b6a5674.setContent(html_6d248a46cff1883c3fffce8dbd69985c);
#
#
#
#         marker_c4b385237b610daa162baa3c91be6709.bindPopup(popup_fba587b1fed8f876008278f47b6a5674)
#         ;
#
#
#
#
#             var marker_e7934a7b98ce99cf8cc401da5ca0761a = L.marker(
#                 [48.21272, 16.37931],
#                 {}
